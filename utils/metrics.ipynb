# %% [markdown]
# ### Metrics

# %%
import pandas as pd
import json
import os
import numpy as np

pd.options.display.max_columns = 999

# %% [markdown]
# Read datasets

# %%
# load tracking data
current_directory = os.getcwd()
path_tracking = os.path.join(os.path.join(os.path.dirname(current_directory),'data'),"tracking_set_0")
print(path_tracking)
game_id = 1

df_tracking = pd.read_parquet(f'{path_tracking}/{game_id}_tracking.parquet')

#           ------------------------------------------------------------        

# load events names
path_event_csv = os.path.join(os.path.dirname(current_directory),'data')
df_event_names = pd.read_csv(os.path.join(path_event_csv,'event_names.csv'))
dict_event_names = df_event_names.set_index('event_type_id').to_dict()['event_description']

# load event data
def load_event_data(file_name, base_path):
    # read in event file
    with open(f'{base_path}/{file_name}') as f:
        data=json.loads(f.read())

    f.close()
    
    # transform data into pandas dataframe
    df_events = pd.json_normalize(data['liveData']['event'])
    
    # preprocess event data and keep relevant information only

    # add timeelapsed to each event
    df_events['timestamp'] = pd.to_datetime(df_events.timeStamp).apply(lambda x: x.timestamp())

    df_events = df_events.query('periodId in [1,2]')

    def add_timeelapsed_to_events(df):
        start_time = df.query('typeId==32')['timestamp'].iloc[0]
        df['timestamp_new'] = np.int64((df['timestamp'] - start_time)*1000)

        df['timeelapsed'] = df['timestamp_new'].apply(lambda x: (40 * round(x/40))/1000)

        return df

    df_events = df_events.groupby('periodId').apply(add_timeelapsed_to_events)

    df_events = df_events.drop(columns=['timeStamp','timestamp','timestamp_new'])
    
    # rename some columns
    df_events = df_events.rename(columns=
        {
            'periodId':'current_phase',
            'typeId':'event_type_id',
            'timeMin':'period_minute',
            'timeSec':'period_second'
        }
    )
    
    return df_events

path_events = os.path.join(os.path.join(os.path.dirname(current_directory),'data'),"first_10_events")
print(path_events)

event_file = f'{game_id}.json'

df_events = load_event_data(
    base_path=path_events,
    file_name=event_file
)

# add event descriptions
df_events['event_description'] = df_events['event_type_id'].map(dict_event_names)

# make a copy of it for later usage
events_all = df_events.copy()

display(df_events.head())
print(df_events['event_description'].unique())


#           ------------------------------------------------------------        


# read in qualifier list
path_data = os.path.join(os.path.dirname(current_directory),'data')
qualifier_names = pd.read_csv(os.path.join(path_data,"qualifier_names.csv"))

# explode coverts each element in each list to a separate row
cols = ['id', 'qualifier']
qualifiers = events_all[cols].explode('qualifier')
display(qualifiers.head())

print("------------")

qualifiers = qualifiers[qualifiers.qualifier.notna()].reset_index(drop=True)
print(qualifiers.shape)
print("------------")
display(qualifiers.head())
print("------------")

# save corresponding event ids for each qualifier
event_ids = qualifiers.id.tolist()

qualifiers = pd.json_normalize(qualifiers[qualifiers.qualifier.notna()]['qualifier'])
print(qualifiers.shape)
print("------------")
display(qualifiers.head())
print("------------")

qualifiers['event_id'] = event_ids
display(qualifiers.head())
print("------------")
qualifiers = qualifiers.merge(qualifier_names, how='left', on='qualifierId')
display(qualifiers.head())
# Out:
# c:\Users\Gabriel\OneDrive\Escritorio\SportsAnalyticsCourse\OptaForum\OptaChallenge_Clustering_Player_Styles\data\tracking_set_0
# c:\Users\Gabriel\OneDrive\Escritorio\SportsAnalyticsCourse\OptaForum\OptaChallenge_Clustering_Player_Styles\data\first_10_events
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\513356439.py:42: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_events = df_events.groupby('periodId').apply(add_timeelapsed_to_events)
#            id  eventId  event_type_id  current_phase  period_minute  \
# 2  2423549045        2             32              1              0
# 3  2423549041        2             32              1              0
# 4  2423549063        3              1              1              0
# 5  2423549097        4              1              1              0
# 6  2423549113        5              1              1              0
#
#    period_second               contestantId  outcome     x     y  \
# 2              0  3c3jcs7vc1t6vz5lev162jyv7        1   0.0   0.0
# 3              0  bx0cdmzr2gwr70ez72dorx82p        1   0.0   0.0
# 4              0  bx0cdmzr2gwr70ez72dorx82p        1  49.9  50.0
# 5              2  bx0cdmzr2gwr70ez72dorx82p        1  31.5  57.2
# 6              7  bx0cdmzr2gwr70ez72dorx82p        1  49.2  95.4
#
#            lastModified                                          qualifier  \
# 2  2022-05-22T03:17:52Z  [{'id': 3586084711, 'qualifierId': 127, 'value...
# 3  2022-05-21T18:59:34Z  [{'id': 3586084701, 'qualifierId': 127, 'value...
# 4  2022-05-22T03:34:41Z  [{'id': 3586084825, 'qualifierId': 56, 'value'...
# 5  2022-05-22T06:37:07Z  [{'id': 3586085043, 'qualifierId': 213, 'value...
# 6  2022-05-22T06:37:06Z  [{'id': 3586085129, 'qualifierId': 212, 'value...
#
#                     playerId lineBreakingPass.linesBroken.value  \
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 5  azuc3tma44xyrbgf5y279o1xx                                  0
# 6  7sep6mx2s67mh5fr3raxu7aei                                  1
#
#                                    passOption.player  \
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...
# 6  [{'playerId': '5qgc6zjc38a5xjl35gs7h3vu1', 'sh...
#
#                                    passTarget.player xThreat.applied  \
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 5  [{'playerId': '7sep6mx2s67mh5fr3raxu7aei', 'sh...    0.0029771626
# 6  [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...    0.0309752524
#
#   lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# 5                                   NaN                             NaN
# 6                          secondToLast                            high
#
#                                      pressure.player xThreat.removed  keyPass  \
# 2                                                NaN             NaN      NaN
# 3                                                NaN             NaN      NaN
# 4                                                NaN             NaN      NaN
# 5                                                NaN             NaN      NaN
# 6  [{'playerId': 'e6ok0deqkoe80184iu509gzu2', 'sh...             NaN      NaN
#
#    assist  timeelapsed event_description
# 2     NaN         0.00      Period start
# 3     NaN         0.00      Period start
# 4     NaN         0.04              Pass
# 5     NaN         2.84              Pass
# 6     NaN         7.88              Pass
# ['Period start' 'Pass' 'Take On' 'Challenge' 'Blocked Pass'
#  'Ball recovery' 'Attempted Tackle' 'Out' 'Ball touch' '50/50'
#  'Dispossessed' 'Tackle' 'Corner Awarded' 'Clearance' 'Offside Pass'
#  'Offside provoked' 'Foul' 'Aerial' 'Keeper pick-up' 'Deleted event'
#  'Interception' 'Error' 'Goal' 'Attempt Saved' 'Save' 'Miss' 'Claim'
#  'Card' 'Start delay' 'End delay' 'Referee Drop Ball' nan 'End'
#  'Player Off' 'Player on' 'Formation change' 'Keeper Sweeper'
#  'Shield ball opp']
#            id                                          qualifier
# 2  2423549045  {'id': 3586084711, 'qualifierId': 127, 'value'...
# 3  2423549041  {'id': 3586084701, 'qualifierId': 127, 'value'...
# 4  2423549063  {'id': 3586084825, 'qualifierId': 56, 'value':...
# 4  2423549063  {'id': 3586084833, 'qualifierId': 213, 'value'...
# 4  2423549063  {'id': 3586084827, 'qualifierId': 140, 'value'...
# ------------
# (9430, 2)
# ------------
#            id                                          qualifier
# 0  2423549045  {'id': 3586084711, 'qualifierId': 127, 'value'...
# 1  2423549041  {'id': 3586084701, 'qualifierId': 127, 'value'...
# 2  2423549063  {'id': 3586084825, 'qualifierId': 56, 'value':...
# 3  2423549063  {'id': 3586084833, 'qualifierId': 213, 'value'...
# 4  2423549063  {'id': 3586084827, 'qualifierId': 140, 'value'...
# ------------
# (9430, 3)
# ------------
#            id  qualifierId          value
# 0  3586084711          127  Right to Left
# 1  3586084701          127  Left to Right
# 2  3586084825           56           Back
# 3  3586084833          213            2.7
# 4  3586084827          140           28.5
# ------------
#            id  qualifierId          value    event_id
# 0  3586084711          127  Right to Left  2423549045
# 1  3586084701          127  Left to Right  2423549041
# 2  3586084825           56           Back  2423549063
# 3  3586084833          213            2.7  2423549063
# 4  3586084827          140           28.5  2423549063
# ------------
#            id  qualifierId          value    event_id          qualifier
# 0  3586084711          127  Right to Left  2423549045  Direction of Play
# 1  3586084701          127  Left to Right  2423549041  Direction of Play
# 2  3586084825           56           Back  2423549063               Zone
# 3  3586084833          213            2.7  2423549063              Angle
# 4  3586084827          140           28.5  2423549063         Pass End X

# %% [markdown]
# Number of passes attempted per player

# %%
def event_per_player(df,event):
    df = df[df['playerId'].notna()]
    try:
        df = df[df['event_description']==event]
        return df.groupby('playerId').size().reset_index(name=event)
    except:
        return False

df = event_per_player(df_events,'Pass')
print(df)
# Out:
#                      playerId  Pass
# 0   2lvit204llltk13iglsa2tjah     2
# 1   3sc349yey596xp2j6xlyt0frp    54
# 2   3vx94h32ahujciraspdayj9t6    19
# 3   4u281v53ges3kimtgac0tidm2    52
# 4   5ak9fwtqlr2pll0nsv5br7p7u    20
# 5   5qgc6zjc38a5xjl35gs7h3vu1    36
# 6   6ekdnbnk56xlxforb5owt3dn9    47
# 7   6j0ogojh2b7poyceg7i3k09yi    64
# 8   6u2ob6fv950r1qve8uejkq2uh    59
# 9   72d5uxwcmvhd6mzthxuvev1sl    38
# 10  7cp51c8zn7y08iyk0hc9ix5nt    66
# 11  7k0r5crdh9blj3edt31zwy0dm     1
# 12  7sep6mx2s67mh5fr3raxu7aei    42
# 13  8f3bhiy6r5eei1n25exhbwr8p    22
# 14  8gkexxgf3pypshhqwg6ibp7o4    35
# 15  8qmm84tue6kuz8e5nhhdhmz8p    41
# 16  96wcx761pzv5ub4sfwsynp51x    54
# 17  976riwm0dz0e74d4l28y3ttcl    55
# 18  a56woizbe4g6jpl3fg4tlgno5    24
# 19   afymbx9eo87zau8mo99pakbu    41
# 20  agwvouyocx93y39g7tmwaojx1     5
# 21  azuc3tma44xyrbgf5y279o1xx    41
# 22  bvbebtykj45j3luvemk8yc4ph    41
# 23  ccu7hw3wrcspl1a18g2ldnsh5     6
# 24  dxb1r4gqgxkngb0pzvfby9iol    13
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x    14
# 26  e6ok0deqkoe80184iu509gzu2    29
# 27  e7e68wlpiqqohpg71oh4vrbl6    22
# 28   fvd7y3f6948713acbas7w3u2    37
# 29    vja0xo3xiuax8eh0b6q3y09    44

# %% [markdown]
# Number of assist and number of key passes

# %%
display(df_passes[df_passes['assist']==True].groupby('playerId').size().reset_index(name='total assist'))
display(df_passes[df_passes['keyPass']==True].groupby('playerId').size().reset_index(name='total assist'))
# Out:
#                     playerId  total assist
# 0  6u2ob6fv950r1qve8uejkq2uh             1
# 1  e6ok0deqkoe80184iu509gzu2             1
#                     playerId  total assist
# 0  5ak9fwtqlr2pll0nsv5br7p7u             1
# 1  6j0ogojh2b7poyceg7i3k09yi             1
# 2  6u2ob6fv950r1qve8uejkq2uh             1
# 3  7sep6mx2s67mh5fr3raxu7aei             3
# 4  8gkexxgf3pypshhqwg6ibp7o4             1
# 5  96wcx761pzv5ub4sfwsynp51x             1
# 6  976riwm0dz0e74d4l28y3ttcl             1
# 7  bvbebtykj45j3luvemk8yc4ph             1
# 8    vja0xo3xiuax8eh0b6q3y09             1

# %% [markdown]
# Xthreat
#
# - 764/1792 values
# - 763 pass, 1 offside pass
# - Mean values

# %%
xthreat = df_events[df_events['xThreat.applied'].notna()]
print(xthreat['event_description'].value_counts())

xthreat = xthreat[xthreat['playerId'].notna()]
xthreat['xThreat.applied'] = pd.to_numeric(xthreat['xThreat.applied'])
xthreat.groupby('playerId')['xThreat.applied'].mean().reset_index(name='xthreat')
# Out:
# Pass            763
# Offside Pass      1
# Name: event_description, dtype: int64
#                      playerId   xthreat
# 0   3sc349yey596xp2j6xlyt0frp  0.017285
# 1   3vx94h32ahujciraspdayj9t6  0.027412
# 2   4u281v53ges3kimtgac0tidm2  0.014667
# 3   5ak9fwtqlr2pll0nsv5br7p7u  0.099773
# 4   5qgc6zjc38a5xjl35gs7h3vu1  0.079592
# 5   6ekdnbnk56xlxforb5owt3dn9  0.000711
# 6   6j0ogojh2b7poyceg7i3k09yi  0.046613
# 7   6u2ob6fv950r1qve8uejkq2uh  0.095785
# 8   72d5uxwcmvhd6mzthxuvev1sl  0.006289
# 9   7cp51c8zn7y08iyk0hc9ix5nt  0.008418
# 10  7sep6mx2s67mh5fr3raxu7aei  0.068849
# 11  8f3bhiy6r5eei1n25exhbwr8p  0.037602
# 12  8gkexxgf3pypshhqwg6ibp7o4  0.037654
# 13  8qmm84tue6kuz8e5nhhdhmz8p  0.008325
# 14  96wcx761pzv5ub4sfwsynp51x  0.028363
# 15  976riwm0dz0e74d4l28y3ttcl  0.022990
# 16  a56woizbe4g6jpl3fg4tlgno5  0.000972
# 17   afymbx9eo87zau8mo99pakbu  0.035754
# 18  agwvouyocx93y39g7tmwaojx1  0.068901
# 19  azuc3tma44xyrbgf5y279o1xx  0.011925
# 20  bvbebtykj45j3luvemk8yc4ph  0.030015
# 21  ccu7hw3wrcspl1a18g2ldnsh5  0.117287
# 22  dxb1r4gqgxkngb0pzvfby9iol  0.037555
# 23  e3kdoxu1kwn2w3wwi1rqhvr9x  0.097706
# 24  e6ok0deqkoe80184iu509gzu2  0.065189
# 25  e7e68wlpiqqohpg71oh4vrbl6  0.067142
# 26   fvd7y3f6948713acbas7w3u2  0.033335
# 27    vja0xo3xiuax8eh0b6q3y09  0.025973

# %% [markdown]
# Total short and long passes and mean distance of pass by player
# - Esta comprovat que tot els pases tenen un qualifier que es length
# - Tots els pases tenen un playerId

# %%
df_passes = df_events[df_events['event_description']=='Pass']
print(df_passes.shape)
print(len(df_passes['id'].unique()))

# ---------- MEAN DISTANCE PER PLAYER --------------------
df_completo = pd.merge(df_passes, qualifiers[qualifiers['qualifier'] == 'Length'], left_on = 'id',right_on='event_id')
df_completo['value'] = pd.to_numeric(df_completo['value'])
display(df_completo.groupby('playerId')['value'].mean().reset_index(name='mean_distance'))

# ---------- TOTAL SHORT AND LONG PASSES PER PLAYER --------------------

df_completo['long'] = df_completo['value']>25

count = df_completo.groupby('playerId')['long'].value_counts().unstack(fill_value=0)

count.columns = ['Short passes', 'Long passes']
display(count)
# Out:
# (1024, 25)
# 1024
#                      playerId  mean_distance
# 0   2lvit204llltk13iglsa2tjah      24.800000
# 1   3sc349yey596xp2j6xlyt0frp      16.642593
# 2   3vx94h32ahujciraspdayj9t6      12.226316
# 3   4u281v53ges3kimtgac0tidm2      17.028846
# 4   5ak9fwtqlr2pll0nsv5br7p7u      18.615000
# 5   5qgc6zjc38a5xjl35gs7h3vu1      18.286111
# 6   6ekdnbnk56xlxforb5owt3dn9      29.331915
# 7   6j0ogojh2b7poyceg7i3k09yi      15.412500
# 8   6u2ob6fv950r1qve8uejkq2uh      16.323729
# 9   72d5uxwcmvhd6mzthxuvev1sl      20.926316
# 10  7cp51c8zn7y08iyk0hc9ix5nt      20.131818
# 11  7k0r5crdh9blj3edt31zwy0dm      20.200000
# 12  7sep6mx2s67mh5fr3raxu7aei      17.104762
# 13  8f3bhiy6r5eei1n25exhbwr8p      16.168182
# 14  8gkexxgf3pypshhqwg6ibp7o4      13.914286
# 15  8qmm84tue6kuz8e5nhhdhmz8p      23.290244
# 16  96wcx761pzv5ub4sfwsynp51x      17.961111
# 17  976riwm0dz0e74d4l28y3ttcl      20.049091
# 18  a56woizbe4g6jpl3fg4tlgno5      28.916667
# 19   afymbx9eo87zau8mo99pakbu      20.768293
# 20  agwvouyocx93y39g7tmwaojx1      22.740000
# 21  azuc3tma44xyrbgf5y279o1xx      18.251220
# 22  bvbebtykj45j3luvemk8yc4ph      16.885366
# 23  ccu7hw3wrcspl1a18g2ldnsh5      26.800000
# 24  dxb1r4gqgxkngb0pzvfby9iol      15.138462
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x      17.771429
# 26  e6ok0deqkoe80184iu509gzu2      13.758621
# 27  e7e68wlpiqqohpg71oh4vrbl6      13.913636
# 28   fvd7y3f6948713acbas7w3u2      17.035135
# 29    vja0xo3xiuax8eh0b6q3y09      14.934091
#                            Short passes  Long passes
# playerId
# 2lvit204llltk13iglsa2tjah             1            1
# 3sc349yey596xp2j6xlyt0frp            44           10
# 3vx94h32ahujciraspdayj9t6            18            1
# 4u281v53ges3kimtgac0tidm2            43            9
# 5ak9fwtqlr2pll0nsv5br7p7u            14            6
# 5qgc6zjc38a5xjl35gs7h3vu1            28            8
# 6ekdnbnk56xlxforb5owt3dn9            24           23
# 6j0ogojh2b7poyceg7i3k09yi            55            9
# 6u2ob6fv950r1qve8uejkq2uh            49           10
# 72d5uxwcmvhd6mzthxuvev1sl            31            7
# 7cp51c8zn7y08iyk0hc9ix5nt            52           14
# 7k0r5crdh9blj3edt31zwy0dm             1            0
# 7sep6mx2s67mh5fr3raxu7aei            32           10
# 8f3bhiy6r5eei1n25exhbwr8p            18            4
# 8gkexxgf3pypshhqwg6ibp7o4            32            3
# 8qmm84tue6kuz8e5nhhdhmz8p            25           16
# 96wcx761pzv5ub4sfwsynp51x            43           11
# 976riwm0dz0e74d4l28y3ttcl            43           12
# a56woizbe4g6jpl3fg4tlgno5            14           10
# afymbx9eo87zau8mo99pakbu             30           11
# agwvouyocx93y39g7tmwaojx1             2            3
# azuc3tma44xyrbgf5y279o1xx            31           10
# bvbebtykj45j3luvemk8yc4ph            34            7
# ccu7hw3wrcspl1a18g2ldnsh5             3            3
# dxb1r4gqgxkngb0pzvfby9iol            12            1
# e3kdoxu1kwn2w3wwi1rqhvr9x            11            3
# e6ok0deqkoe80184iu509gzu2            25            4
# e7e68wlpiqqohpg71oh4vrbl6            21            1
# fvd7y3f6948713acbas7w3u2             28            9
# vja0xo3xiuax8eh0b6q3y09              40            4

# %% [markdown]
# Number of shots attempted (Goal + miss)

# %%
df_shots = df_events[df_events['event_description'].isin(['Goal','Miss'])]

df_shots.groupby('playerId').size().reset_index(name='shots')
# Out:
#                     playerId  shots
# 0  3vx94h32ahujciraspdayj9t6      1
# 1  4u281v53ges3kimtgac0tidm2      1
# 2  6j0ogojh2b7poyceg7i3k09yi      1
# 3  6u2ob6fv950r1qve8uejkq2uh      1
# 4  8gkexxgf3pypshhqwg6ibp7o4      1
# 5  8qmm84tue6kuz8e5nhhdhmz8p      1
# 6  e3kdoxu1kwn2w3wwi1rqhvr9x      4

# %% [markdown]
# Line Breaking Passes & last line Breaking Passes

# %%
df_events[(df_events['lineBreakingPass.linesBroken.value'].notna())]
# Out:
#               id  eventId  event_type_id  current_phase  period_minute  \
# 5     2423549097        4              1              1              0
# 6     2423549113        5              1              1              0
# 15    2423549219       11              1              1              0
# 17    2423549257       13              1              1              0
# 20    2423549347        5              1              1              0
# ...          ...      ...            ...            ...            ...
# 1749  2423663961      890              1              2             91
# 1756  2423668971      816              1              2             92
# 1759  2423664769      798              1              2             92
# 1774  2423665291      805              1              2             92
# 1783  2423665895      810              1              2             93
#
#       period_second               contestantId  outcome     x     y  \
# 5                 2  bx0cdmzr2gwr70ez72dorx82p        1  31.5  57.2
# 6                 7  bx0cdmzr2gwr70ez72dorx82p        1  49.2  95.4
# 15               21  bx0cdmzr2gwr70ez72dorx82p        1  37.2  56.4
# 17               26  bx0cdmzr2gwr70ez72dorx82p        1  32.5  46.7
# 20               30  3c3jcs7vc1t6vz5lev162jyv7        1  35.5  64.4
# ...             ...                        ...      ...   ...   ...
# 1749             20  bx0cdmzr2gwr70ez72dorx82p        1  23.9  80.2
# 1756              6  3c3jcs7vc1t6vz5lev162jyv7        1  41.6  33.6
# 1759             13  3c3jcs7vc1t6vz5lev162jyv7        1  63.7  19.5
# 1774             43  3c3jcs7vc1t6vz5lev162jyv7        1  24.4  50.3
# 1783             23  3c3jcs7vc1t6vz5lev162jyv7        1  59.9  49.8
#
#               lastModified                                          qualifier  \
# 5     2022-05-22T06:37:07Z  [{'id': 3586085043, 'qualifierId': 213, 'value...
# 6     2022-05-22T06:37:06Z  [{'id': 3586085129, 'qualifierId': 212, 'value...
# 15    2022-05-22T06:37:01Z  [{'id': 3586085771, 'qualifierId': 140, 'value...
# 17    2022-05-22T06:36:59Z  [{'id': 3586085949, 'qualifierId': 212, 'value...
# 20    2022-05-22T06:36:58Z  [{'id': 3586086323, 'qualifierId': 213, 'value...
# ...                    ...                                                ...
# 1749  2022-05-22T06:19:00Z  [{'id': 3586718331, 'qualifierId': 56, 'value'...
# 1756  2022-05-22T06:18:58Z  [{'id': 3587615859, 'qualifierId': 178}, {'id'...
# 1759  2022-05-22T06:18:57Z  [{'id': 3586722773, 'qualifierId': 56, 'value'...
# 1774  2022-05-22T06:18:50Z  [{'id': 3586725655, 'qualifierId': 56, 'value'...
# 1783  2022-05-22T06:18:46Z  [{'id': 3587618025, 'qualifierId': 178}, {'id'...
#
#                        playerId lineBreakingPass.linesBroken.value  \
# 5     azuc3tma44xyrbgf5y279o1xx                                  0
# 6     7sep6mx2s67mh5fr3raxu7aei                                  1
# 15    azuc3tma44xyrbgf5y279o1xx                                  0
# 17    azuc3tma44xyrbgf5y279o1xx                                  2
# 20    72d5uxwcmvhd6mzthxuvev1sl                                  1
# ...                         ...                                ...
# 1749  6u2ob6fv950r1qve8uejkq2uh                                  1
# 1756  72d5uxwcmvhd6mzthxuvev1sl                                  0
# 1759  96wcx761pzv5ub4sfwsynp51x                                  0
# 1774  6ekdnbnk56xlxforb5owt3dn9                                  1
# 1783  agwvouyocx93y39g7tmwaojx1                                  0
#
#                                       passOption.player  \
# 5     [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...
# 6     [{'playerId': '5qgc6zjc38a5xjl35gs7h3vu1', 'sh...
# 15    [{'playerId': '5qgc6zjc38a5xjl35gs7h3vu1', 'sh...
# 17    [{'playerId': '4u281v53ges3kimtgac0tidm2', 'sh...
# 20    [{'playerId': '96wcx761pzv5ub4sfwsynp51x', 'sh...
# ...                                                 ...
# 1749  [{'playerId': '7cp51c8zn7y08iyk0hc9ix5nt', 'sh...
# 1756  [{'playerId': '96wcx761pzv5ub4sfwsynp51x', 'sh...
# 1759  [{'playerId': '7ty1wdxxnusgkl34k5raipbl5', 'sh...
# 1774  [{'playerId': '3sc349yey596xp2j6xlyt0frp', 'sh...
# 1783                                                NaN
#
#                                       passTarget.player xThreat.applied  \
# 5     [{'playerId': '7sep6mx2s67mh5fr3raxu7aei', 'sh...    0.0029771626
# 6     [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...    0.0309752524
# 15    [{'playerId': '6j0ogojh2b7poyceg7i3k09yi', 'sh...    0.0027582049
# 17    [{'playerId': 'e7e68wlpiqqohpg71oh4vrbl6', 'sh...    0.0055874586
# 20    [{'playerId': '3vx94h32ahujciraspdayj9t6', 'sh...    0.0203064084
# ...                                                 ...             ...
# 1749  [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...    0.0239186883
# 1756  [{'playerId': '6ekdnbnk56xlxforb5owt3dn9', 'sh...    0.0103171468
# 1759  [{'playerId': 'ccu7hw3wrcspl1a18g2ldnsh5', 'sh...    0.0428849459
# 1774  [{'playerId': 'ccu7hw3wrcspl1a18g2ldnsh5', 'sh...    0.0080752969
# 1783                                                NaN             NaN
#
#      lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 5                                      NaN                             NaN
# 6                             secondToLast                            high
# 15                                     NaN                             NaN
# 17                            secondToLast                            high
# 20                            secondToLast                          medium
# ...                                    ...                             ...
# 1749                          secondToLast                          medium
# 1756                                   NaN                             NaN
# 1759                                   NaN                             NaN
# 1774                                   NaN                            high
# 1783                                   NaN                             NaN
#
#                                         pressure.player xThreat.removed  \
# 5                                                   NaN             NaN
# 6     [{'playerId': 'e6ok0deqkoe80184iu509gzu2', 'sh...             NaN
# 15                                                  NaN             NaN
# 17    [{'playerId': 'e6ok0deqkoe80184iu509gzu2', 'sh...             NaN
# 20    [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...             NaN
# ...                                                 ...             ...
# 1749  [{'playerId': 'fvd7y3f6948713acbas7w3u2', 'shi...             NaN
# 1756                                                NaN             NaN
# 1759                                                NaN             NaN
# 1774  [{'playerId': '5ak9fwtqlr2pll0nsv5br7p7u', 'sh...             NaN
# 1783                                                NaN             NaN
#
#       keyPass  assist  timeelapsed event_description
# 5         NaN     NaN         2.84              Pass
# 6         NaN     NaN         7.88              Pass
# 15        NaN     NaN        21.72              Pass
# 17        NaN     NaN        26.32              Pass
# 20        NaN     NaN        30.28              Pass
# ...       ...     ...          ...               ...
# 1749      NaN     NaN      2780.96              Pass
# 1756      NaN     NaN      2826.00              Pass
# 1759      NaN     NaN      2833.84              Pass
# 1774      NaN     NaN      2863.04              Pass
# 1783      NaN     NaN      2903.20              Pass
#
# [398 rows x 25 columns]

# %%
print(df_events.shape)
df_1 = df_events[(df_events['lineBreakingPass.linesBroken.value'].notna()) & (df_events['lineBreakingPass.linesBroken.value']!=0)].groupby('playerId').size().reset_index(name='line breaking passes')
df_2 = df_events[df_events['lineBreakingPass.lastLineBroken.value'].notna()].groupby('playerId').size().reset_index(name='last_line breaking passes')
# Out:
# (1786, 25)
#                      playerId  line breaking passes
# 0   3sc349yey596xp2j6xlyt0frp                    10
# 1   3vx94h32ahujciraspdayj9t6                     4
# 2   4u281v53ges3kimtgac0tidm2                    26
# 3   5ak9fwtqlr2pll0nsv5br7p7u                     4
# 4   5qgc6zjc38a5xjl35gs7h3vu1                     8
# 5   6ekdnbnk56xlxforb5owt3dn9                    33
# 6   6j0ogojh2b7poyceg7i3k09yi                    28
# 7   6u2ob6fv950r1qve8uejkq2uh                    20
# 8   72d5uxwcmvhd6mzthxuvev1sl                    23
# 9   7cp51c8zn7y08iyk0hc9ix5nt                    27
# 10  7sep6mx2s67mh5fr3raxu7aei                    10
# 11  8f3bhiy6r5eei1n25exhbwr8p                     8
# 12  8gkexxgf3pypshhqwg6ibp7o4                    14
# 13  8qmm84tue6kuz8e5nhhdhmz8p                    11
# 14  96wcx761pzv5ub4sfwsynp51x                    28
# 15  976riwm0dz0e74d4l28y3ttcl                    28
# 16  a56woizbe4g6jpl3fg4tlgno5                    19
# 17   afymbx9eo87zau8mo99pakbu                    12
# 18  agwvouyocx93y39g7tmwaojx1                     1
# 19  azuc3tma44xyrbgf5y279o1xx                    27
# 20  bvbebtykj45j3luvemk8yc4ph                    17
# 21  dxb1r4gqgxkngb0pzvfby9iol                     5
# 22  e3kdoxu1kwn2w3wwi1rqhvr9x                     1
# 23  e6ok0deqkoe80184iu509gzu2                     4
# 24  e7e68wlpiqqohpg71oh4vrbl6                     6
# 25   fvd7y3f6948713acbas7w3u2                    10
# 26    vja0xo3xiuax8eh0b6q3y09                    14
#                      playerId  line breaking passes
# 0   3vx94h32ahujciraspdayj9t6                     2
# 1   4u281v53ges3kimtgac0tidm2                     5
# 2   5ak9fwtqlr2pll0nsv5br7p7u                     2
# 3   6ekdnbnk56xlxforb5owt3dn9                     4
# 4   6j0ogojh2b7poyceg7i3k09yi                     7
# 5   6u2ob6fv950r1qve8uejkq2uh                     8
# 6   72d5uxwcmvhd6mzthxuvev1sl                     4
# 7   7cp51c8zn7y08iyk0hc9ix5nt                     5
# 8   7sep6mx2s67mh5fr3raxu7aei                     6
# 9   8f3bhiy6r5eei1n25exhbwr8p                     3
# 10  8gkexxgf3pypshhqwg6ibp7o4                     5
# 11  8qmm84tue6kuz8e5nhhdhmz8p                     1
# 12  96wcx761pzv5ub4sfwsynp51x                    12
# 13  976riwm0dz0e74d4l28y3ttcl                     6
# 14  a56woizbe4g6jpl3fg4tlgno5                     1
# 15   afymbx9eo87zau8mo99pakbu                     6
# 16  azuc3tma44xyrbgf5y279o1xx                     4
# 17  bvbebtykj45j3luvemk8yc4ph                     3
# 18  dxb1r4gqgxkngb0pzvfby9iol                     2
# 19  e7e68wlpiqqohpg71oh4vrbl6                     2
# 20   fvd7y3f6948713acbas7w3u2                     5
# 21    vja0xo3xiuax8eh0b6q3y09                     6

# %% [markdown]
# Pressure value in Pass, Goal, Miss, Ball touch, Control

# %%
listss = ['Pass','Goal','Miss','Ball touch','Control']
print(df_events[df_events['event_description'].isin(listss)].isna().sum())
print(df_events[df_events['event_description'].isin(listss)].shape)
# Out:
# id                                          0
# eventId                                     0
# event_type_id                               0
# current_phase                               0
# period_minute                               0
# period_second                               0
# contestantId                                0
# outcome                                     0
# x                                           0
# y                                           0
# lastModified                                0
# qualifier                                   0
# playerId                                    0
# lineBreakingPass.linesBroken.value        703
# passOption.player                         170
# passTarget.player                         170
# xThreat.applied                           338
# lineBreakingPass.lastLineBroken.value    1002
# pressure.pressureReceived.value           443
# pressure.player                           443
# xThreat.removed                           933
# keyPass                                  1090
# assist                                   1099
# timeelapsed                                 0
# event_description                           0
# dtype: int64
# (1101, 25)

# %% [markdown]
# Number of take ons and number of succesfull take ons

# %%
df_events[df_events['event_description']=='Take On']['outcome'].value_counts()
display(df_events[df_events['event_description']=='Take On'].groupby('playerId').size().reset_index(name='take on'))

condition = (df_events['event_description'] == 'Take On') & (df_events['outcome'] == 1)
display(df_events[condition].groupby('playerId').size().reset_index(name='take on succesfull'))
# Out:
#                      playerId  take on
# 0   3sc349yey596xp2j6xlyt0frp        1
# 1   3vx94h32ahujciraspdayj9t6        4
# 2   4u281v53ges3kimtgac0tidm2        1
# 3   5qgc6zjc38a5xjl35gs7h3vu1        3
# 4   6j0ogojh2b7poyceg7i3k09yi        3
# 5   6u2ob6fv950r1qve8uejkq2uh        4
# 6   7cp51c8zn7y08iyk0hc9ix5nt        1
# 7   7sep6mx2s67mh5fr3raxu7aei        2
# 8   8f3bhiy6r5eei1n25exhbwr8p        1
# 9   8qmm84tue6kuz8e5nhhdhmz8p        1
# 10  96wcx761pzv5ub4sfwsynp51x        1
# 11  976riwm0dz0e74d4l28y3ttcl        1
# 12   afymbx9eo87zau8mo99pakbu        1
# 13  agwvouyocx93y39g7tmwaojx1        2
# 14  e6ok0deqkoe80184iu509gzu2        4
# 15  e7e68wlpiqqohpg71oh4vrbl6        3
# 16   fvd7y3f6948713acbas7w3u2        1
#                      playerId  take on succesfull
# 0   3sc349yey596xp2j6xlyt0frp                   1
# 1   4u281v53ges3kimtgac0tidm2                   1
# 2   5qgc6zjc38a5xjl35gs7h3vu1                   1
# 3   6j0ogojh2b7poyceg7i3k09yi                   3
# 4   6u2ob6fv950r1qve8uejkq2uh                   3
# 5   7cp51c8zn7y08iyk0hc9ix5nt                   1
# 6   7sep6mx2s67mh5fr3raxu7aei                   2
# 7   8f3bhiy6r5eei1n25exhbwr8p                   1
# 8   976riwm0dz0e74d4l28y3ttcl                   1
# 9    afymbx9eo87zau8mo99pakbu                   1
# 10  agwvouyocx93y39g7tmwaojx1                   1
# 11  e6ok0deqkoe80184iu509gzu2                   1
# 12  e7e68wlpiqqohpg71oh4vrbl6                   1
# 13   fvd7y3f6948713acbas7w3u2                   1

# %%
# load data
current_directory = os.getcwd()
path_tracking = os.path.join(os.path.join(os.path.dirname(current_directory),'data'),"tracking_set_0")
print(path_tracking)
game_id = 1

path_events = os.path.join(os.path.join(os.path.dirname(current_directory),'data'),"first_10_events")
print(path_events)

# load the tracking data
df_tracking = pd.read_parquet(f'{path_tracking}/{game_id}_tracking.parquet')

# load event names
path_event_csv = os.path.join(os.path.dirname(current_directory),'data')
df_event_names = pd.read_csv(os.path.join(path_event_csv,'event_names.csv'))
dict_event_names = df_event_names.set_index('event_type_id').to_dict()['event_description']
# Out:
# c:\Users\Gabriel\OneDrive\Escritorio\SportsAnalyticsCourse\OptaForum\OptaChallenge_Clustering_Player_Styles\data\tracking_set_0
# c:\Users\Gabriel\OneDrive\Escritorio\SportsAnalyticsCourse\OptaForum\OptaChallenge_Clustering_Player_Styles\data\first_10_events

# %% [markdown]
# Merge events with tracking

# %%
df_all = pd.merge(df_events,df_tracking, on =['timeelapsed','current_phase'])
display(df_all.head(2))
# Out:
#            id  eventId  event_type_id  current_phase  period_minute  \
# 0  2423549045        2             32              1              0
# 1  2423549045        2             32              1              0
#
#    period_second               contestantId  outcome    x    y  \
# 0              0  3c3jcs7vc1t6vz5lev162jyv7        1  0.0  0.0
# 1              0  3c3jcs7vc1t6vz5lev162jyv7        1  0.0  0.0
#
#            lastModified                                          qualifier  \
# 0  2022-05-22T03:17:52Z  [{'id': 3586084711, 'qualifierId': 127, 'value...
# 1  2022-05-22T03:17:52Z  [{'id': 3586084711, 'qualifierId': 127, 'value...
#
#   playerId lineBreakingPass.linesBroken.value passOption.player  \
# 0      NaN                                NaN               NaN
# 1      NaN                                NaN               NaN
#
#   passTarget.player xThreat.applied lineBreakingPass.lastLineBroken.value  \
# 0               NaN             NaN                                   NaN
# 1               NaN             NaN                                   NaN
#
#   pressure.pressureReceived.value pressure.player xThreat.removed  keyPass  \
# 0                             NaN             NaN             NaN      NaN
# 1                             NaN             NaN             NaN      NaN
#
#    assist  timeelapsed event_description               team_id_opta  \
# 0     NaN          0.0      Period start  bx0cdmzr2gwr70ez72dorx82p
# 1     NaN          0.0      Period start  bx0cdmzr2gwr70ez72dorx82p
#
#                    player_id  jersey_no      pos_x     pos_y     speed  \
# 0  azuc3tma44xyrbgf5y279o1xx       16.0 -19.477912  4.240699  0.464332
# 1  6u2ob6fv950r1qve8uejkq2uh        1.0  -0.117343 -0.234231  0.328293
#
#    frame_count  team_id       acc   speed_x   speed_y dop  \
# 0        10000      2.0  0.727075 -0.121969 -0.357286   L
# 1        10000      2.0  0.899067  0.224221  0.126503   L
#
#           team_in_possession
# 0  bx0cdmzr2gwr70ez72dorx82p
# 1  bx0cdmzr2gwr70ez72dorx82p

# %% [markdown]
# Average shot distance per player

# %%
df_shots = df_all[(df_all['event_description'].isin(['Goal','Miss'])) & (df_all['player_id']==df_all['playerId'])]

df_shots['pos_x'] = pd.to_numeric(df_shots['pos_x'])
mask = df_shots['dop'] == 'R'
df_shots.loc[mask, 'dop'] = 'L'
df_shots.loc[mask, 'pos_x'] *= -1

# determine the distance
target_point = (52.5, 0)

df_shots['distance_to_target'] = np.sqrt((df_shots['pos_x'] - target_point[0])**2 + (df_shots['pos_y'] - target_point[1])**2)

display(df_shots.groupby('playerId')['distance_to_target'].mean().reset_index(name='avg_shot_distance'))
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_10496\1525952707.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots['pos_x'] = pd.to_numeric(df_shots['pos_x'])
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_10496\1525952707.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots['distance_to_target'] = np.sqrt((df_shots['pos_x'] - target_point[0])**2 + (df_shots['pos_y'] - target_point[1])**2)
#                     playerId  avg_shot_distance
# 0  3vx94h32ahujciraspdayj9t6          20.554468
# 1  4u281v53ges3kimtgac0tidm2          11.381902
# 2  6j0ogojh2b7poyceg7i3k09yi          27.086573
# 3  6u2ob6fv950r1qve8uejkq2uh          24.234017
# 4  8gkexxgf3pypshhqwg6ibp7o4          20.302314
# 5  8qmm84tue6kuz8e5nhhdhmz8p           5.237487
# 6  e3kdoxu1kwn2w3wwi1rqhvr9x          21.619386

# %% [markdown]
# Defensive metrics (Tackles, Fouls, attempted tackles, aerial, blocked pass, ball recovery, interception)

# %%
df_events[df_events['event_description']=='Blocked Pass']

df_events[df_events['eventId']==8]

#qualifiers[qualifiers['event_id']==2423549165]
# Out:
#             id  eventId  event_type_id  current_phase  period_minute  \
# 11  2423549155        8              1              1              0
# 24  2423549479        8              1              1              0
#
#     period_second               contestantId  outcome     x     y  \
# 11             12  bx0cdmzr2gwr70ez72dorx82p        0  57.8  83.6
# 24             41  3c3jcs7vc1t6vz5lev162jyv7        1  21.7  82.5
#
#             lastModified                                          qualifier  \
# 11  2022-05-22T06:37:04Z  [{'id': 3586095441, 'qualifierId': 141, 'value...
# 24  2022-05-22T06:36:54Z  [{'id': 3587585583, 'qualifierId': 178}, {'id'...
#
#                      playerId lineBreakingPass.linesBroken.value  \
# 11  6j0ogojh2b7poyceg7i3k09yi                                NaN
# 24  3vx94h32ahujciraspdayj9t6                                NaN
#
#                                     passOption.player  \
# 11  [{'playerId': '7sep6mx2s67mh5fr3raxu7aei', 'sh...
# 24  [{'playerId': '6ekdnbnk56xlxforb5owt3dn9', 'sh...
#
#                                     passTarget.player xThreat.applied  \
# 11  [{'playerId': '7sep6mx2s67mh5fr3raxu7aei', 'sh...             NaN
# 24  [{'playerId': '72d5uxwcmvhd6mzthxuvev1sl', 'sh...    0.0005321801
#
#    lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 11                                   NaN                            high
# 24                                   NaN                            high
#
#                                       pressure.player xThreat.removed  \
# 11  [{'playerId': 'e6ok0deqkoe80184iu509gzu2', 'sh...    0.0053730607
# 24  [{'playerId': '4u281v53ges3kimtgac0tidm2', 'sh...             NaN
#
#     keyPass  assist  timeelapsed event_description
# 11      NaN     NaN        12.92              Pass
# 24      NaN     NaN        41.40              Pass

# %% [markdown]
# Quantitat de pases en cada zona amb pressió alta i el seu % de success

# %%
df_passes = df_all[(df_all['event_description']=='Pass') & (df_all['player_id']==df_all['playerId'])]

df_passes['pos_x'] = pd.to_numeric(df_passes['pos_x'])
mask = df_passes['dop'] == 'R'
df_passes.loc[mask, 'dop'] = 'L'
df_passes.loc[mask, 'pos_x'] *= -1
df_passes.loc[mask, 'pos_y'] *= -1


condiciones = [
    (df_passes['pos_x'] <= 0, 'defensive'),
    ((df_passes['pos_x'] > 0) & (-34 <= df_passes['pos_y']) & (df_passes['pos_y'] < -11), 'left_wing'),
    ((df_passes['pos_x'] > 0) & (11 < df_passes['pos_y']) & (df_passes['pos_y'] <= 34), 'right_wing'),
    ((df_passes['pos_x'] > 0) & (df_passes['pos_x'] <= 26.25) & (-11 <= df_passes['pos_y']) & (df_passes['pos_y'] <= 11), 'center_down'),
    ((26.25 < df_passes['pos_x']) & (df_passes['pos_x'] <= 52.5) & (-11 <= df_passes['pos_y']) & (df_passes['pos_y'] <= 11), 'center_up')
]

df_passes['zone'] = np.select([cond[0] for cond in condiciones], [cond[1] for cond in condiciones], default='unknown')
display(df_passes.head())
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_8196\4117690597.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_passes['pos_x'] = pd.to_numeric(df_passes['pos_x'])
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_8196\4117690597.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_passes['zone'] = np.select([cond[0] for cond in condiciones], [cond[1] for cond in condiciones], default='unknown')
#              id  eventId  event_type_id  current_phase  period_minute  \
# 50   2423549063        3              1              1              0
# 73   2423549097        4              1              1              0
# 98   2423549113        5              1              1              0
# 124  2423549127        6              1              1              0
# 188  2423549153        7              1              1              0
#
#      period_second               contestantId  outcome     x     y  \
# 50               0  bx0cdmzr2gwr70ez72dorx82p        1  49.9  50.0
# 73               2  bx0cdmzr2gwr70ez72dorx82p        1  31.5  57.2
# 98               7  bx0cdmzr2gwr70ez72dorx82p        1  49.2  95.4
# 124              9  bx0cdmzr2gwr70ez72dorx82p        1  72.1  88.0
# 188             11  bx0cdmzr2gwr70ez72dorx82p        1  63.6  94.3
#
#              lastModified                                          qualifier  \
# 50   2022-05-22T03:34:41Z  [{'id': 3586084825, 'qualifierId': 56, 'value'...
# 73   2022-05-22T06:37:07Z  [{'id': 3586085043, 'qualifierId': 213, 'value...
# 98   2022-05-22T06:37:06Z  [{'id': 3586085129, 'qualifierId': 212, 'value...
# 124  2022-05-22T06:37:05Z  [{'id': 3586085187, 'qualifierId': 56, 'value'...
# 188  2022-05-22T06:37:04Z  [{'id': 3586085373, 'qualifierId': 140, 'value...
#
#                       playerId lineBreakingPass.linesBroken.value  \
# 50   6u2ob6fv950r1qve8uejkq2uh                                NaN
# 73   azuc3tma44xyrbgf5y279o1xx                                  0
# 98   7sep6mx2s67mh5fr3raxu7aei                                  1
# 124  e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
# 188  6u2ob6fv950r1qve8uejkq2uh                                NaN
#
#                                      passOption.player  \
# 50                                                 NaN
# 73   [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...
# 98   [{'playerId': '5qgc6zjc38a5xjl35gs7h3vu1', 'sh...
# 124  [{'playerId': '7cp51c8zn7y08iyk0hc9ix5nt', 'sh...
# 188  [{'playerId': '5qgc6zjc38a5xjl35gs7h3vu1', 'sh...
#
#                                      passTarget.player xThreat.applied  \
# 50                                                 NaN             NaN
# 73   [{'playerId': '7sep6mx2s67mh5fr3raxu7aei', 'sh...    0.0029771626
# 98   [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...    0.0309752524
# 124  [{'playerId': '6u2ob6fv950r1qve8uejkq2uh', 'sh...    0.0338825583
# 188  [{'playerId': '6j0ogojh2b7poyceg7i3k09yi', 'sh...    0.0111802518
#
#     lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 50                                    NaN                             NaN
# 73                                    NaN                             NaN
# 98                           secondToLast                            high
# 124                                   NaN                            high
# 188                                   NaN                            high
#
#                                        pressure.player xThreat.removed  \
# 50                                                 NaN             NaN
# 73                                                 NaN             NaN
# 98   [{'playerId': 'e6ok0deqkoe80184iu509gzu2', 'sh...             NaN
# 124  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 188  [{'playerId': 'fvd7y3f6948713acbas7w3u2', 'shi...             NaN
#
#      keyPass  assist  timeelapsed event_description  \
# 50       NaN     NaN         0.04              Pass
# 73       NaN     NaN         2.84              Pass
# 98       NaN     NaN         7.88              Pass
# 124      NaN     NaN         9.16              Pass
# 188      NaN     NaN        11.56              Pass
#
#                   team_id_opta                  player_id  jersey_no  \
# 50   bx0cdmzr2gwr70ez72dorx82p  6u2ob6fv950r1qve8uejkq2uh        1.0
# 73   bx0cdmzr2gwr70ez72dorx82p  azuc3tma44xyrbgf5y279o1xx       16.0
# 98   bx0cdmzr2gwr70ez72dorx82p  7sep6mx2s67mh5fr3raxu7aei       13.0
# 124  bx0cdmzr2gwr70ez72dorx82p  e3kdoxu1kwn2w3wwi1rqhvr9x       17.0
# 188  bx0cdmzr2gwr70ez72dorx82p  6u2ob6fv950r1qve8uejkq2uh        1.0
#
#          pos_x      pos_y     speed  frame_count  team_id       acc   speed_x  \
# 50   -0.107400  -0.228648  0.361032        10001      2.0  0.945378  0.273445
# 73  -19.847447   4.775255  2.387325        10071      2.0  0.285220  0.019709
# 98   -0.955286  30.978778  2.309112        10197      2.0 -0.607715  2.298279
# 124  23.980289  25.796733  4.552663        10229      2.0 -0.535470 -1.150168
# 188  14.403023  29.964194  3.729682        10289      2.0  0.169329 -0.737431
#
#       speed_y dop         team_in_possession        zone
# 50   0.152210   L  bx0cdmzr2gwr70ez72dorx82p   defensive
# 73   2.403938   L  bx0cdmzr2gwr70ez72dorx82p   defensive
# 98  -0.214493   L  bx0cdmzr2gwr70ez72dorx82p   defensive
# 124  4.411378   L  bx0cdmzr2gwr70ez72dorx82p  right_wing
# 188  3.661325   L  bx0cdmzr2gwr70ez72dorx82p  right_wing

# %%
df_passes['pressure.pressureReceived.value']=df_passes['pressure.pressureReceived.value'].fillna('NaN')
df_p_total=df_passes[df_passes['outcome']==1].groupby(['playerId','zone','pressure.pressureReceived.value']).size().reset_index(name='completed_passes')

total = df_passes.groupby(['playerId','zone','pressure.pressureReceived.value']).size().reset_index(name='total_passes')

df_p_total = pd.merge(df_p_total,total,on=['playerId','zone','pressure.pressureReceived.value'])
df_p_total["% succes"] = df_p_total['completed_passes'] /df_p_total['total_passes']
display(df_p_total)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_8196\1383183134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_passes['pressure.pressureReceived.value']=df_passes['pressure.pressureReceived.value'].fillna('NaN')
#                       playerId         zone pressure.pressureReceived.value  \
# 0    2lvit204llltk13iglsa2tjah  center_down                             NaN
# 1    3sc349yey596xp2j6xlyt0frp    defensive                             NaN
# 2    3sc349yey596xp2j6xlyt0frp    defensive                            high
# 3    3sc349yey596xp2j6xlyt0frp    defensive                          medium
# 4    3sc349yey596xp2j6xlyt0frp   right_wing                             NaN
# ..                         ...          ...                             ...
# 226    vja0xo3xiuax8eh0b6q3y09    left_wing                            high
# 227    vja0xo3xiuax8eh0b6q3y09    left_wing                             low
# 228    vja0xo3xiuax8eh0b6q3y09    left_wing                          medium
# 229    vja0xo3xiuax8eh0b6q3y09   right_wing                             NaN
# 230    vja0xo3xiuax8eh0b6q3y09      unknown                             NaN
#
#      completed_passes  total_passes  % succes
# 0                   1             1  1.000000
# 1                  11            14  0.785714
# 2                   8            12  0.666667
# 3                  10            12  0.833333
# 4                   3             4  0.750000
# ..                ...           ...       ...
# 226                 4             5  0.800000
# 227                 1             1  1.000000
# 228                 4             4  1.000000
# 229                 1             1  1.000000
# 230                 1             1  1.000000
#
# [231 rows x 6 columns]

# %% [markdown]
# Defensive metrics (Tackles, Fouls, attempted tackles, aerial, blocked pass, ball recovery, interception)
#
# Tackle – Unsuccessful Take-on/Dispossessed. A tackle is awarded if a player wins the ball from another player who is in possession. If he is attempting to beat the tackler, the other player will get an unsuccessful Take-on. If he is in possession but not attempting to “beat” his man, then he will get a dispossessed.

# %% [markdown]
# Quanta pressio fa cada jugador?   High = 0.99, medium = 0.66, low = 0.33

# %%
df_events[df_events['pressure.player'].notna()]['event_description'].unique()
# Out:
# array(['Pass', 'Take On', 'Ball touch', 'Dispossessed', 'Clearance',
#        'Offside Pass', 'Foul', 'Interception', 'Goal', 'Attempt Saved',
#        'Miss', 'Claim', 'Keeper pick-up', 'Save'], dtype=object)

# %% [markdown]
# Pass, Take on, Ball touch, Dispossessed, Clearance, Interception, Goal, Miss

# %%
pressure_events = df_events[(df_events['event_description'].isin(['Pass','Take On','Ball touch',
                                                                 'Dispossessed','Clearance','Offisde Pass',
                                                                 'Foul','Interception',
                                                                  'Goal','Miss']))
                                                                 & df_events['pressure.player'].notna()]

# per cada fila, agafar els jugadors que estan presionant 
#i afegirlos a un dataframe amb la intensitat de la pressió 
print(pressure_events.shape)
df_pressure = pd.DataFrame(columns=['playerid', 'intensity'])
for index,row in pressure_events.iterrows():
   pressurePlayers = row['pressure.player']
   players = [d['playerId'] for d in pressurePlayers]
   intensity = [d['intensity'] for d in pressurePlayers]
   player_intensity_dict = dict(zip(players, intensity))
   temp_df = pd.DataFrame(list(player_intensity_dict.items()), columns=['playerid', 'intensity'])
   df_pressure = pd.concat([df_pressure, temp_df], ignore_index=True)

display(df_pressure)


df_pressure['pressure_value'] = np.where(df_pressure['intensity'] == 'high', 0.99, 
                                         np.where(df_pressure['intensity'] == 'medium', 0.66, 
                                                  np.where(df_pressure['intensity'] == 'low', 0.33, 0)))

display(df_pressure)

df_pressure_players = df_pressure.groupby('playerid')['pressure_value'].sum().reset_index(name='pressure_total_value')

display(df_pressure_players)

df_minutes = df_tracking.groupby('player_id').size().reset_index(name='counts')

# fem sumatori i ho dividim entre 60 = 94.62 min!

# max counts = 141928, per tant, 141928/94.62  = 1500 per tant 1500 counts son 1 minut.

df_minutes['minutes'] = df_minutes['counts'] / 1500

df_minutes.drop('counts',axis=1,inplace=True)
df_minutes = df_minutes[df_minutes['player_id'] != 'aaaaaaaaaaaaaaaaaaaaaaaaa']

display(df_minutes)

df_pressure_players=pd.merge(df_pressure_players,df_minutes, left_on = 'playerid',right_on='player_id')
df_pressure_players['pressure_90'] = df_pressure_players['pressure_total_value'] / df_pressure_players['minutes']*90
display(df_pressure_players)
# Out:
# (771, 25)
#                       playerid intensity
# 0    e6ok0deqkoe80184iu509gzu2      high
# 1    8qmm84tue6kuz8e5nhhdhmz8p      high
# 2    96wcx761pzv5ub4sfwsynp51x      high
# 3     fvd7y3f6948713acbas7w3u2      high
# 4     afymbx9eo87zau8mo99pakbu       low
# ..                         ...       ...
# 954  6j0ogojh2b7poyceg7i3k09yi      high
# 955  7k0r5crdh9blj3edt31zwy0dm      high
# 956  5ak9fwtqlr2pll0nsv5br7p7u      high
# 957  7k0r5crdh9blj3edt31zwy0dm      high
# 958  5ak9fwtqlr2pll0nsv5br7p7u      high
#
# [959 rows x 2 columns]
#                       playerid intensity  pressure_value
# 0    e6ok0deqkoe80184iu509gzu2      high            0.99
# 1    8qmm84tue6kuz8e5nhhdhmz8p      high            0.99
# 2    96wcx761pzv5ub4sfwsynp51x      high            0.99
# 3     fvd7y3f6948713acbas7w3u2      high            0.99
# 4     afymbx9eo87zau8mo99pakbu       low            0.33
# ..                         ...       ...             ...
# 954  6j0ogojh2b7poyceg7i3k09yi      high            0.99
# 955  7k0r5crdh9blj3edt31zwy0dm      high            0.99
# 956  5ak9fwtqlr2pll0nsv5br7p7u      high            0.99
# 957  7k0r5crdh9blj3edt31zwy0dm      high            0.99
# 958  5ak9fwtqlr2pll0nsv5br7p7u      high            0.99
#
# [959 rows x 3 columns]
#                      playerid  pressure_total_value
# 0   2lvit204llltk13iglsa2tjah                 11.55
# 1   3sc349yey596xp2j6xlyt0frp                 30.69
# 2   3vx94h32ahujciraspdayj9t6                 27.72
# 3   4u281v53ges3kimtgac0tidm2                 38.28
# 4   5ak9fwtqlr2pll0nsv5br7p7u                 11.88
# 5   5qgc6zjc38a5xjl35gs7h3vu1                 22.11
# 6   6j0ogojh2b7poyceg7i3k09yi                 34.98
# 7   6u2ob6fv950r1qve8uejkq2uh                 49.17
# 8   72d5uxwcmvhd6mzthxuvev1sl                  8.25
# 9   7cp51c8zn7y08iyk0hc9ix5nt                 12.21
# 10  7k0r5crdh9blj3edt31zwy0dm                  9.90
# 11  7sep6mx2s67mh5fr3raxu7aei                 13.53
# 12  7ty1wdxxnusgkl34k5raipbl5                  6.60
# 13  8f3bhiy6r5eei1n25exhbwr8p                  9.90
# 14  8gkexxgf3pypshhqwg6ibp7o4                 59.73
# 15  8qmm84tue6kuz8e5nhhdhmz8p                 36.63
# 16  96wcx761pzv5ub4sfwsynp51x                 59.40
# 17  976riwm0dz0e74d4l28y3ttcl                 23.43
# 18   afymbx9eo87zau8mo99pakbu                 43.56
# 19  agwvouyocx93y39g7tmwaojx1                 14.85
# 20  azuc3tma44xyrbgf5y279o1xx                  7.92
# 21  bvbebtykj45j3luvemk8yc4ph                  5.28
# 22  ccu7hw3wrcspl1a18g2ldnsh5                  4.95
# 23  dxb1r4gqgxkngb0pzvfby9iol                  9.90
# 24  e3kdoxu1kwn2w3wwi1rqhvr9x                 37.29
# 25  e6ok0deqkoe80184iu509gzu2                 33.33
# 26  e7e68wlpiqqohpg71oh4vrbl6                 32.67
# 27   fvd7y3f6948713acbas7w3u2                 78.87
# 28    vja0xo3xiuax8eh0b6q3y09                 20.46
#                     player_id    minutes
# 0   2lvit204llltk13iglsa2tjah  18.538667
# 1   3sc349yey596xp2j6xlyt0frp  94.618667
# 2   3vx94h32ahujciraspdayj9t6  62.395333
# 3   4u281v53ges3kimtgac0tidm2  94.618667
# 4   5ak9fwtqlr2pll0nsv5br7p7u  38.255333
# 5   5qgc6zjc38a5xjl35gs7h3vu1  68.112000
# 6   6ekdnbnk56xlxforb5owt3dn9  94.618667
# 7   6j0ogojh2b7poyceg7i3k09yi  94.618667
# 8   6u2ob6fv950r1qve8uejkq2uh  94.618667
# 9   72d5uxwcmvhd6mzthxuvev1sl  94.618667
# 10  7cp51c8zn7y08iyk0hc9ix5nt  94.618667
# 11  7k0r5crdh9blj3edt31zwy0dm  26.505333
# 12  7sep6mx2s67mh5fr3raxu7aei  46.094667
# 13  7ty1wdxxnusgkl34k5raipbl5  10.188667
# 14  8f3bhiy6r5eei1n25exhbwr8p  48.524000
# 15  8gkexxgf3pypshhqwg6ibp7o4  84.430000
# 16  8qmm84tue6kuz8e5nhhdhmz8p  94.618667
# 17  96wcx761pzv5ub4sfwsynp51x  94.618667
# 18  976riwm0dz0e74d4l28y3ttcl  94.618667
# 19  a56woizbe4g6jpl3fg4tlgno5  94.618667
# 21   afymbx9eo87zau8mo99pakbu  84.278667
# 22  agwvouyocx93y39g7tmwaojx1  32.222000
# 23  azuc3tma44xyrbgf5y279o1xx  46.094667
# 24  bvbebtykj45j3luvemk8yc4ph  48.524000
# 25  ccu7hw3wrcspl1a18g2ldnsh5  10.338667
# 26  dxb1r4gqgxkngb0pzvfby9iol  38.122000
# 27  e3kdoxu1kwn2w3wwi1rqhvr9x  94.618667
# 28  e6ok0deqkoe80184iu509gzu2  76.078667
# 29  e7e68wlpiqqohpg71oh4vrbl6  56.362000
# 30   fvd7y3f6948713acbas7w3u2  94.618667
# 31    vja0xo3xiuax8eh0b6q3y09  56.495333
#                      playerid  pressure_total_value  \
# 0   2lvit204llltk13iglsa2tjah                 11.55
# 1   3sc349yey596xp2j6xlyt0frp                 30.69
# 2   3vx94h32ahujciraspdayj9t6                 27.72
# 3   4u281v53ges3kimtgac0tidm2                 38.28
# 4   5ak9fwtqlr2pll0nsv5br7p7u                 11.88
# 5   5qgc6zjc38a5xjl35gs7h3vu1                 22.11
# 6   6j0ogojh2b7poyceg7i3k09yi                 34.98
# 7   6u2ob6fv950r1qve8uejkq2uh                 49.17
# 8   72d5uxwcmvhd6mzthxuvev1sl                  8.25
# 9   7cp51c8zn7y08iyk0hc9ix5nt                 12.21
# 10  7k0r5crdh9blj3edt31zwy0dm                  9.90
# 11  7sep6mx2s67mh5fr3raxu7aei                 13.53
# 12  7ty1wdxxnusgkl34k5raipbl5                  6.60
# 13  8f3bhiy6r5eei1n25exhbwr8p                  9.90
# 14  8gkexxgf3pypshhqwg6ibp7o4                 59.73
# 15  8qmm84tue6kuz8e5nhhdhmz8p                 36.63
# 16  96wcx761pzv5ub4sfwsynp51x                 59.40
# 17  976riwm0dz0e74d4l28y3ttcl                 23.43
# 18   afymbx9eo87zau8mo99pakbu                 43.56
# 19  agwvouyocx93y39g7tmwaojx1                 14.85
# 20  azuc3tma44xyrbgf5y279o1xx                  7.92
# 21  bvbebtykj45j3luvemk8yc4ph                  5.28
# 22  ccu7hw3wrcspl1a18g2ldnsh5                  4.95
# 23  dxb1r4gqgxkngb0pzvfby9iol                  9.90
# 24  e3kdoxu1kwn2w3wwi1rqhvr9x                 37.29
# 25  e6ok0deqkoe80184iu509gzu2                 33.33
# 26  e7e68wlpiqqohpg71oh4vrbl6                 32.67
# 27   fvd7y3f6948713acbas7w3u2                 78.87
# 28    vja0xo3xiuax8eh0b6q3y09                 20.46
#
#                     player_id    minutes  pressure_90
# 0   2lvit204llltk13iglsa2tjah  18.538667    56.071994
# 1   3sc349yey596xp2j6xlyt0frp  94.618667    29.191914
# 2   3vx94h32ahujciraspdayj9t6  62.395333    39.983759
# 3   4u281v53ges3kimtgac0tidm2  94.618667    36.411420
# 4   5ak9fwtqlr2pll0nsv5br7p7u  38.255333    27.949044
# 5   5qgc6zjc38a5xjl35gs7h3vu1  68.112000    29.215116
# 6   6j0ogojh2b7poyceg7i3k09yi  94.618667    33.272504
# 7   6u2ob6fv950r1qve8uejkq2uh  94.618667    46.769841
# 8   72d5uxwcmvhd6mzthxuvev1sl  94.618667     7.847289
# 9   7cp51c8zn7y08iyk0hc9ix5nt  94.618667    11.613987
# 10  7k0r5crdh9blj3edt31zwy0dm  26.505333    33.615876
# 11  7sep6mx2s67mh5fr3raxu7aei  46.094667    26.417373
# 12  7ty1wdxxnusgkl34k5raipbl5  10.188667    58.300072
# 13  8f3bhiy6r5eei1n25exhbwr8p  48.524000    18.362048
# 14  8gkexxgf3pypshhqwg6ibp7o4  84.430000    63.670496
# 15  8qmm84tue6kuz8e5nhhdhmz8p  94.618667    34.841962
# 16  96wcx761pzv5ub4sfwsynp51x  94.618667    56.500479
# 17  976riwm0dz0e74d4l28y3ttcl  94.618667    22.286300
# 18   afymbx9eo87zau8mo99pakbu  84.278667    46.517110
# 19  agwvouyocx93y39g7tmwaojx1  32.222000    41.477872
# 20  azuc3tma44xyrbgf5y279o1xx  46.094667    15.463828
# 21  bvbebtykj45j3luvemk8yc4ph  48.524000     9.793092
# 22  ccu7hw3wrcspl1a18g2ldnsh5  10.338667    43.090663
# 23  dxb1r4gqgxkngb0pzvfby9iol  38.122000    23.372331
# 24  e3kdoxu1kwn2w3wwi1rqhvr9x  94.618667    35.469745
# 25  e6ok0deqkoe80184iu509gzu2  76.078667    39.428924
# 26  e7e68wlpiqqohpg71oh4vrbl6  56.362000    52.168127
# 27   fvd7y3f6948713acbas7w3u2  94.618667    75.020081
# 28    vja0xo3xiuax8eh0b6q3y09  56.495333    32.593843

# %%
df_pos = df_tracking[['player_id','pos_x','pos_y','dop']]

# All with the same direction
df_pos['pos_x'] = pd.to_numeric(df_pos['pos_x'])
mask = df_pos['dop'] == 'R'
df_pos.loc[mask, 'dop'] = 'L'
df_pos.loc[mask, 'pos_x'] *= -1
df_pos.loc[mask, 'pos_y'] *= -1

# Divide the field into zones

# Into two zones
df_pos['ofensive'] = np.where(df_pos['pos_x'] > 0, 1, 0)
df_pos['defensive'] = np.where(df_pos['pos_x'] <= 0, 1, 0)

# More especific
df_pos['left_wing'] = np.where((df_pos['pos_x'] > 0) & (-34 <= df_pos['pos_y']) & (df_pos['pos_y'] < -11), 1, 0)
df_pos['right_wing'] = np.where((df_pos['pos_x'] > 0) & (11 < df_pos['pos_y']) & (df_pos['pos_y'] <= 34), 1, 0)
df_pos['center_down'] = np.where((df_pos['pos_x'] > 0) & (df_pos['pos_x'] <= 26.25) & (-11 <= df_pos['pos_y']) & (df_pos['pos_y'] <= 11), 1, 0)
df_pos['center_up'] = np.where((26.25 < df_pos['pos_x']) & (df_pos['pos_x'] <= 52.5) & (-11 <= df_pos['pos_y']) & (df_pos['pos_y'] <= 11), 1, 0)

pos_total = df_pos.groupby('player_id').agg({'ofensive': 'sum', 'defensive': 'sum',
                                             'left_wing': 'sum','right_wing': 'sum',
                                             'center_up': 'sum','center_down': 'sum'}).reset_index()

pos_total = pd.merge(pos_total, df_pos.groupby('player_id').size().reset_index(name='total'),
                      on='player_id', how='inner')

pos_total['ofensive %'] = pos_total['ofensive'] / pos_total['total']
pos_total['defensive %'] = pos_total['defensive'] / pos_total['total']
pos_total['left_wing %'] = pos_total['left_wing'] / pos_total['total']
pos_total['right_wing %'] = pos_total['right_wing'] / pos_total['total']
pos_total['center_up %'] = pos_total['center_up'] / pos_total['total']
pos_total['center_down %'] = pos_total['center_down'] / pos_total['total']

pos_pct_total = pos_total[['player_id','ofensive %','defensive %','left_wing %','right_wing %','center_up %','center_down %']]

#display(pos_pct_total)

pos_pct_total = pos_pct_total[pos_pct_total['ofensive %']>0.5]
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\1829907660.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['pos_x'] = pd.to_numeric(df_pos['pos_x'])
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\1829907660.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['ofensive'] = np.where(df_pos['pos_x'] > 0, 1, 0)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\1829907660.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['defensive'] = np.where(df_pos['pos_x'] <= 0, 1, 0)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\1829907660.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['left_wing'] = np.where((df_pos['pos_x'] > 0) & (-34 <= df_pos['pos_y']) & (df_pos['pos_y'] < -11), 1, 0)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\1829907660.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['right_wing'] = np.where((df_pos['pos_x'] > 0) & (11 < df_pos['pos_y']) & (df_pos['pos_y'] <= 34), 1, 0)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\1829907660.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['center_down'] = np.where((df_pos['pos_x'] > 0) & (df_pos['pos_x'] <= 26.25) & (-11 <= df_pos['pos_y']) & (df_pos['pos_y'] <= 11), 1, 0)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_15916\1829907660.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['center_up'] = np.where((26.25 < df_pos['pos_x']) & (df_pos['pos_x'] <= 52.5) & (-11 <= df_pos['pos_y']) & (df_pos['pos_y'] <= 11), 1, 0)

# %%
players_offensive = pos_pct_total['player_id'].tolist()

df_pressure_off_players = df_pressure_players[df_pressure_players['player_id'].isin(players_offensive)]
display(df_pressure_off_players)
# Out:
#                      playerid  pressure_total_value  \
# 0   2lvit204llltk13iglsa2tjah                 11.55
# 2   3vx94h32ahujciraspdayj9t6                 27.72
# 4   5ak9fwtqlr2pll0nsv5br7p7u                 11.88
# 5   5qgc6zjc38a5xjl35gs7h3vu1                 22.11
# 6   6j0ogojh2b7poyceg7i3k09yi                 34.98
# 7   6u2ob6fv950r1qve8uejkq2uh                 49.17
# 10  7k0r5crdh9blj3edt31zwy0dm                  9.90
# 12  7ty1wdxxnusgkl34k5raipbl5                  6.60
# 19  agwvouyocx93y39g7tmwaojx1                 14.85
# 23  dxb1r4gqgxkngb0pzvfby9iol                  9.90
# 24  e3kdoxu1kwn2w3wwi1rqhvr9x                 37.29
# 25  e6ok0deqkoe80184iu509gzu2                 33.33
# 26  e7e68wlpiqqohpg71oh4vrbl6                 32.67
# 28    vja0xo3xiuax8eh0b6q3y09                 20.46
#
#                     player_id    minutes  pressure_90
# 0   2lvit204llltk13iglsa2tjah  18.538667    56.071994
# 2   3vx94h32ahujciraspdayj9t6  62.395333    39.983759
# 4   5ak9fwtqlr2pll0nsv5br7p7u  38.255333    27.949044
# 5   5qgc6zjc38a5xjl35gs7h3vu1  68.112000    29.215116
# 6   6j0ogojh2b7poyceg7i3k09yi  94.618667    33.272504
# 7   6u2ob6fv950r1qve8uejkq2uh  94.618667    46.769841
# 10  7k0r5crdh9blj3edt31zwy0dm  26.505333    33.615876
# 12  7ty1wdxxnusgkl34k5raipbl5  10.188667    58.300072
# 19  agwvouyocx93y39g7tmwaojx1  32.222000    41.477872
# 23  dxb1r4gqgxkngb0pzvfby9iol  38.122000    23.372331
# 24  e3kdoxu1kwn2w3wwi1rqhvr9x  94.618667    35.469745
# 25  e6ok0deqkoe80184iu509gzu2  76.078667    39.428924
# 26  e7e68wlpiqqohpg71oh4vrbl6  56.362000    52.168127
# 28    vja0xo3xiuax8eh0b6q3y09  56.495333    32.593843

# %%
df_pressure_off_players.to_csv('pressure_off_players.csv',index=False)

# %% [markdown]
# Shots on target

# %%
df_events[df_events['event_description'].isin(['Goal','Miss'])]
#qualifiers[qualifiers['event_id']==2423568337]
# Out:
#               id  eventId  event_type_id  current_phase  period_minute  \
# 184   2423557685       90             16              1              8
# 297   2423564565      127             13              1             13
# 349   2423568337      185             16              1             16
# 1412  2423637613      722             13              2             67
# 1517  2423644617      774             16              2             74
# 1552  2423647403      792             16              2             76
# 1580  2423651317      811             13              2             80
# 1617  2423653225      832             16              2             81
# 1762  2423664859      801             13              2             92
# 1771  2423665119      899             13              2             92
#
#       period_second               contestantId  outcome     x     y  \
# 184               1  3c3jcs7vc1t6vz5lev162jyv7        1  77.3  38.5
# 297              42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 349              51  3c3jcs7vc1t6vz5lev162jyv7        1  76.7  57.0
# 1412             49  bx0cdmzr2gwr70ez72dorx82p        1  73.7  45.4
# 1517              4  bx0cdmzr2gwr70ez72dorx82p        1  88.5  50.0
# 1552             33  bx0cdmzr2gwr70ez72dorx82p        1  85.4  49.9
# 1580              5  bx0cdmzr2gwr70ez72dorx82p        1  88.8  56.2
# 1617             51  bx0cdmzr2gwr70ez72dorx82p        1  96.1  58.1
# 1762             19  3c3jcs7vc1t6vz5lev162jyv7        1  94.1  47.7
# 1771             32  bx0cdmzr2gwr70ez72dorx82p        1  51.0  74.6
#
#               lastModified                                          qualifier  \
# 184   2022-05-22T06:35:22Z  [{'id': 3586133347, 'qualifierId': 20}, {'id':...
# 297   2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 349   2022-05-22T06:33:34Z  [{'id': 3586920981, 'qualifierId': 395, 'value...
# 1412  2022-05-22T06:22:08Z  [{'id': 3586569373, 'qualifierId': 56, 'value'...
# 1517  2022-05-22T04:00:16Z  [{'id': 3586609837, 'qualifierId': 56, 'value'...
# 1552  2022-05-22T06:20:45Z  [{'id': 3586625857, 'qualifierId': 22}, {'id':...
# 1580  2022-05-22T06:20:25Z  [{'id': 3586648109, 'qualifierId': 328}, {'id'...
# 1617  2022-05-22T06:44:01Z  [{'id': 3586664227, 'qualifierId': 214}, {'id'...
# 1762  2022-05-22T07:31:26Z  [{'id': 3586724977, 'qualifierId': 24}, {'id':...
# 1771  2022-05-22T06:18:51Z  [{'id': 3586949291, 'qualifierId': 231, 'value...
#
#                        playerId lineBreakingPass.linesBroken.value  \
# 184   3vx94h32ahujciraspdayj9t6                                NaN
# 297   6u2ob6fv950r1qve8uejkq2uh                                NaN
# 349   8gkexxgf3pypshhqwg6ibp7o4                                NaN
# 1412  6j0ogojh2b7poyceg7i3k09yi                                NaN
# 1517  e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
# 1552  e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
# 1580  4u281v53ges3kimtgac0tidm2                                NaN
# 1617  e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
# 1762  8qmm84tue6kuz8e5nhhdhmz8p                                NaN
# 1771  e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
#
#      passOption.player passTarget.player xThreat.applied  \
# 184                NaN               NaN             NaN
# 297                NaN               NaN             NaN
# 349                NaN               NaN             NaN
# 1412               NaN               NaN             NaN
# 1517               NaN               NaN             NaN
# 1552               NaN               NaN             NaN
# 1580               NaN               NaN             NaN
# 1617               NaN               NaN             NaN
# 1762               NaN               NaN             NaN
# 1771               NaN               NaN             NaN
#
#      lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 184                                    NaN                          medium
# 297                                    NaN                            high
# 349                                    NaN                            high
# 1412                                   NaN                            high
# 1517                                   NaN                             NaN
# 1552                                   NaN                          medium
# 1580                                   NaN                            high
# 1617                                   NaN                            high
# 1762                                   NaN                             NaN
# 1771                                   NaN                            high
#
#                                         pressure.player xThreat.removed  \
# 184   [{'playerId': 'azuc3tma44xyrbgf5y279o1xx', 'sh...             NaN
# 297   [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 349   [{'playerId': '4u281v53ges3kimtgac0tidm2', 'sh...             NaN
# 1412  [{'playerId': '8gkexxgf3pypshhqwg6ibp7o4', 'sh...             NaN
# 1517                                                NaN             NaN
# 1552  [{'playerId': '8gkexxgf3pypshhqwg6ibp7o4', 'sh...             NaN
# 1580  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 1617  [{'playerId': 'afymbx9eo87zau8mo99pakbu', 'shi...             NaN
# 1762                                                NaN             NaN
# 1771  [{'playerId': 'ccu7hw3wrcspl1a18g2ldnsh5', 'sh...             NaN
#
#       keyPass  assist  timeelapsed event_description
# 184       NaN     NaN       481.16              Goal
# 297       NaN     NaN       822.28              Miss
# 349       NaN     NaN      1011.52              Goal
# 1412      NaN     NaN      1369.44              Miss
# 1517      NaN     NaN      1744.84              Goal
# 1552      NaN     NaN      1893.96              Goal
# 1580      NaN     NaN      2105.64              Miss
# 1617      NaN     NaN      2211.04              Goal
# 1762      NaN     NaN      2839.60              Miss
# 1771      NaN     NaN      2852.24              Miss

# %%
df_all = pd.merge(df_events,df_tracking, on =['timeelapsed','current_phase'])
display(df_all.head(2))

df_all_miss = df_all[df_all['id']==2423564565]
display(df_all_miss)
# Out:
#            id  eventId  event_type_id  current_phase  period_minute  \
# 0  2423549045        2             32              1              0
# 1  2423549045        2             32              1              0
#
#    period_second               contestantId  outcome    x    y  \
# 0              0  3c3jcs7vc1t6vz5lev162jyv7        1  0.0  0.0
# 1              0  3c3jcs7vc1t6vz5lev162jyv7        1  0.0  0.0
#
#            lastModified                                          qualifier  \
# 0  2022-05-22T03:17:52Z  [{'id': 3586084711, 'qualifierId': 127, 'value...
# 1  2022-05-22T03:17:52Z  [{'id': 3586084711, 'qualifierId': 127, 'value...
#
#   playerId lineBreakingPass.linesBroken.value passOption.player  \
# 0      NaN                                NaN               NaN
# 1      NaN                                NaN               NaN
#
#   passTarget.player xThreat.applied lineBreakingPass.lastLineBroken.value  \
# 0               NaN             NaN                                   NaN
# 1               NaN             NaN                                   NaN
#
#   pressure.pressureReceived.value pressure.player xThreat.removed  keyPass  \
# 0                             NaN             NaN             NaN      NaN
# 1                             NaN             NaN             NaN      NaN
#
#    assist  timeelapsed event_description               team_id_opta  \
# 0     NaN          0.0      Period start  bx0cdmzr2gwr70ez72dorx82p
# 1     NaN          0.0      Period start  bx0cdmzr2gwr70ez72dorx82p
#
#                    player_id  jersey_no      pos_x     pos_y     speed  \
# 0  azuc3tma44xyrbgf5y279o1xx       16.0 -19.477912  4.240699  0.464332
# 1  6u2ob6fv950r1qve8uejkq2uh        1.0  -0.117343 -0.234231  0.328293
#
#    frame_count  team_id       acc   speed_x   speed_y dop  \
# 0        10000      2.0  0.727075 -0.121969 -0.357286   L
# 1        10000      2.0  0.899067  0.224221  0.126503   L
#
#           team_in_possession
# 0  bx0cdmzr2gwr70ez72dorx82p
# 1  bx0cdmzr2gwr70ez72dorx82p
#               id  eventId  event_type_id  current_phase  period_minute  \
# 6785  2423564565      127             13              1             13
# 6786  2423564565      127             13              1             13
# 6787  2423564565      127             13              1             13
# 6788  2423564565      127             13              1             13
# 6789  2423564565      127             13              1             13
# 6790  2423564565      127             13              1             13
# 6791  2423564565      127             13              1             13
# 6792  2423564565      127             13              1             13
# 6793  2423564565      127             13              1             13
# 6794  2423564565      127             13              1             13
# 6795  2423564565      127             13              1             13
# 6796  2423564565      127             13              1             13
# 6797  2423564565      127             13              1             13
# 6798  2423564565      127             13              1             13
# 6799  2423564565      127             13              1             13
# 6800  2423564565      127             13              1             13
# 6801  2423564565      127             13              1             13
# 6802  2423564565      127             13              1             13
# 6803  2423564565      127             13              1             13
# 6804  2423564565      127             13              1             13
# 6805  2423564565      127             13              1             13
# 6806  2423564565      127             13              1             13
# 6807  2423564565      127             13              1             13
#
#       period_second               contestantId  outcome     x     y  \
# 6785             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6786             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6787             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6788             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6789             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6790             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6791             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6792             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6793             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6794             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6795             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6796             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6797             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6798             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6799             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6800             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6801             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6802             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6803             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6804             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6805             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6806             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
# 6807             42  bx0cdmzr2gwr70ez72dorx82p        1  76.4  44.0
#
#               lastModified                                          qualifier  \
# 6785  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6786  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6787  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6788  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6789  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6790  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6791  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6792  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6793  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6794  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6795  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6796  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6797  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6798  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6799  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6800  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6801  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6802  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6803  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6804  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6805  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6806  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
# 6807  2022-05-22T06:34:14Z  [{'id': 3586168999, 'qualifierId': 18}, {'id':...
#
#                        playerId lineBreakingPass.linesBroken.value  \
# 6785  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6786  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6787  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6788  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6789  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6790  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6791  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6792  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6793  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6794  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6795  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6796  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6797  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6798  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6799  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6800  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6801  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6802  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6803  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6804  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6805  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6806  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 6807  6u2ob6fv950r1qve8uejkq2uh                                NaN
#
#      passOption.player passTarget.player xThreat.applied  \
# 6785               NaN               NaN             NaN
# 6786               NaN               NaN             NaN
# 6787               NaN               NaN             NaN
# 6788               NaN               NaN             NaN
# 6789               NaN               NaN             NaN
# 6790               NaN               NaN             NaN
# 6791               NaN               NaN             NaN
# 6792               NaN               NaN             NaN
# 6793               NaN               NaN             NaN
# 6794               NaN               NaN             NaN
# 6795               NaN               NaN             NaN
# 6796               NaN               NaN             NaN
# 6797               NaN               NaN             NaN
# 6798               NaN               NaN             NaN
# 6799               NaN               NaN             NaN
# 6800               NaN               NaN             NaN
# 6801               NaN               NaN             NaN
# 6802               NaN               NaN             NaN
# 6803               NaN               NaN             NaN
# 6804               NaN               NaN             NaN
# 6805               NaN               NaN             NaN
# 6806               NaN               NaN             NaN
# 6807               NaN               NaN             NaN
#
#      lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 6785                                   NaN                            high
# 6786                                   NaN                            high
# 6787                                   NaN                            high
# 6788                                   NaN                            high
# 6789                                   NaN                            high
# 6790                                   NaN                            high
# 6791                                   NaN                            high
# 6792                                   NaN                            high
# 6793                                   NaN                            high
# 6794                                   NaN                            high
# 6795                                   NaN                            high
# 6796                                   NaN                            high
# 6797                                   NaN                            high
# 6798                                   NaN                            high
# 6799                                   NaN                            high
# 6800                                   NaN                            high
# 6801                                   NaN                            high
# 6802                                   NaN                            high
# 6803                                   NaN                            high
# 6804                                   NaN                            high
# 6805                                   NaN                            high
# 6806                                   NaN                            high
# 6807                                   NaN                            high
#
#                                         pressure.player xThreat.removed  \
# 6785  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6786  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6787  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6788  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6789  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6790  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6791  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6792  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6793  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6794  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6795  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6796  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6797  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6798  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6799  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6800  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6801  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6802  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6803  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6804  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6805  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6806  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
# 6807  [{'playerId': '8qmm84tue6kuz8e5nhhdhmz8p', 'sh...             NaN
#
#       keyPass  assist  timeelapsed event_description  \
# 6785      NaN     NaN       822.28              Miss
# 6786      NaN     NaN       822.28              Miss
# 6787      NaN     NaN       822.28              Miss
# 6788      NaN     NaN       822.28              Miss
# 6789      NaN     NaN       822.28              Miss
# 6790      NaN     NaN       822.28              Miss
# 6791      NaN     NaN       822.28              Miss
# 6792      NaN     NaN       822.28              Miss
# 6793      NaN     NaN       822.28              Miss
# 6794      NaN     NaN       822.28              Miss
# 6795      NaN     NaN       822.28              Miss
# 6796      NaN     NaN       822.28              Miss
# 6797      NaN     NaN       822.28              Miss
# 6798      NaN     NaN       822.28              Miss
# 6799      NaN     NaN       822.28              Miss
# 6800      NaN     NaN       822.28              Miss
# 6801      NaN     NaN       822.28              Miss
# 6802      NaN     NaN       822.28              Miss
# 6803      NaN     NaN       822.28              Miss
# 6804      NaN     NaN       822.28              Miss
# 6805      NaN     NaN       822.28              Miss
# 6806      NaN     NaN       822.28              Miss
# 6807      NaN     NaN       822.28              Miss
#
#                    team_id_opta                  player_id  jersey_no  \
# 6785  3c3jcs7vc1t6vz5lev162jyv7  8gkexxgf3pypshhqwg6ibp7o4        6.0
# 6786  3c3jcs7vc1t6vz5lev162jyv7  976riwm0dz0e74d4l28y3ttcl       20.0
# 6787  3c3jcs7vc1t6vz5lev162jyv7  3vx94h32ahujciraspdayj9t6       17.0
# 6788  3c3jcs7vc1t6vz5lev162jyv7   fvd7y3f6948713acbas7w3u2       21.0
# 6789  3c3jcs7vc1t6vz5lev162jyv7   afymbx9eo87zau8mo99pakbu       26.0
# 6790  3c3jcs7vc1t6vz5lev162jyv7  8qmm84tue6kuz8e5nhhdhmz8p       16.0
# 6791  3c3jcs7vc1t6vz5lev162jyv7  96wcx761pzv5ub4sfwsynp51x        3.0
# 6792  3c3jcs7vc1t6vz5lev162jyv7  72d5uxwcmvhd6mzthxuvev1sl        5.0
# 6793  3c3jcs7vc1t6vz5lev162jyv7  3sc349yey596xp2j6xlyt0frp       29.0
# 6794  3c3jcs7vc1t6vz5lev162jyv7  6ekdnbnk56xlxforb5owt3dn9       18.0
# 6795  bbbbbbbbbbbbbbbbbbbbbbbbb  aaaaaaaaaaaaaaaaaaaaaaaaa        1.0
# 6796  bx0cdmzr2gwr70ez72dorx82p  7cp51c8zn7y08iyk0hc9ix5nt        5.0
# 6797  bx0cdmzr2gwr70ez72dorx82p  5qgc6zjc38a5xjl35gs7h3vu1        7.0
# 6798  bx0cdmzr2gwr70ez72dorx82p  azuc3tma44xyrbgf5y279o1xx       16.0
# 6799  bx0cdmzr2gwr70ez72dorx82p  e3kdoxu1kwn2w3wwi1rqhvr9x       17.0
# 6800  bx0cdmzr2gwr70ez72dorx82p  a56woizbe4g6jpl3fg4tlgno5       12.0
# 6801  bx0cdmzr2gwr70ez72dorx82p    vja0xo3xiuax8eh0b6q3y09        4.0
# 6802  bx0cdmzr2gwr70ez72dorx82p  e7e68wlpiqqohpg71oh4vrbl6       11.0
# 6803  bx0cdmzr2gwr70ez72dorx82p  6j0ogojh2b7poyceg7i3k09yi       22.0
# 6804  bx0cdmzr2gwr70ez72dorx82p  6u2ob6fv950r1qve8uejkq2uh        1.0
# 6805  bx0cdmzr2gwr70ez72dorx82p  7sep6mx2s67mh5fr3raxu7aei       13.0
# 6806  bx0cdmzr2gwr70ez72dorx82p  4u281v53ges3kimtgac0tidm2       23.0
# 6807  3c3jcs7vc1t6vz5lev162jyv7  e6ok0deqkoe80184iu509gzu2       14.0
#
#           pos_x      pos_y      speed  frame_count  team_id         acc  \
# 6785  21.499467 -15.481811   4.408298        30557      1.0   -0.830438
# 6786  34.040936 -10.525651   2.917017        30557      1.0   -0.327736
# 6787   3.519819  -7.337529   2.374300        30557      1.0   -0.788773
# 6788  14.431847  -5.836049   4.143205        30557      1.0   -0.977393
# 6789  28.558585   6.563891   4.558537        30557      1.0   -0.670126
# 6790  30.743602  -2.535393   4.882442        30557      1.0    3.839610
# 6791  26.022510  -3.964728   5.755434        30557      1.0   -1.431339
# 6792  32.965227  -5.050043   1.953662        30557      1.0   -3.534887
# 6793  31.596956 -17.772419   5.380581        30557      1.0   -0.349731
# 6794  49.362800  -1.066902   0.520900        30557      1.0    1.099635
# 6795  29.780000  -5.080000  27.268650        30557      4.0  166.812644
# 6796  17.428181 -13.851888   1.213216        30557      2.0   -0.493184
# 6797  21.718406   7.941442   3.949053        30557      2.0   -0.687037
# 6798  -2.576405  -6.002493   1.313711        30557      2.0    0.014794
# 6799  31.544835 -13.393198   2.779483        30557      2.0   -1.899822
# 6800 -33.449071  -1.039375   0.831273        30557      2.0   -0.395588
# 6801  12.752139 -20.391048   3.281252        30557      2.0   -0.169385
# 6802  27.870259 -21.317593   4.579835        30557      2.0   -0.942946
# 6803   8.697821  -7.403093   2.861142        30557      2.0   -1.157712
# 6804  28.582098  -3.901475   5.218900        30557      2.0   -1.900711
# 6805   8.183176   9.618540   3.260632        30557      2.0   -0.177168
# 6806   0.823531 -26.328223   1.624756        30557      2.0   -0.212403
# 6807   2.170193 -26.317463   1.587724        30557      1.0   -0.237893
#
#         speed_x   speed_y   dop         team_in_possession
# 6785   3.357054  2.855477     R  bx0cdmzr2gwr70ez72dorx82p
# 6786   2.908747  0.190629     R  bx0cdmzr2gwr70ez72dorx82p
# 6787   0.779988  2.244148     R  bx0cdmzr2gwr70ez72dorx82p
# 6788   3.285065  2.522008     R  bx0cdmzr2gwr70ez72dorx82p
# 6789   4.382103 -1.251649     R  bx0cdmzr2gwr70ez72dorx82p
# 6790   2.430562 -4.245598     R  bx0cdmzr2gwr70ez72dorx82p
# 6791   5.176525  2.511721     R  bx0cdmzr2gwr70ez72dorx82p
# 6792   1.752391 -0.850783     R  bx0cdmzr2gwr70ez72dorx82p
# 6793   4.776794  2.474837     R  bx0cdmzr2gwr70ez72dorx82p
# 6794  -0.460566 -0.324449     R  bx0cdmzr2gwr70ez72dorx82p
# 6795  27.235394 -1.346325  None  bx0cdmzr2gwr70ez72dorx82p
# 6796   0.342770  1.160310     L  bx0cdmzr2gwr70ez72dorx82p
# 6797   3.790905  1.101551     L  bx0cdmzr2gwr70ez72dorx82p
# 6798   1.063831  0.769318     L  bx0cdmzr2gwr70ez72dorx82p
# 6799   2.448964  1.304678     L  bx0cdmzr2gwr70ez72dorx82p
# 6800   0.603809  0.570081     L  bx0cdmzr2gwr70ez72dorx82p
# 6801   2.658065  1.921772     L  bx0cdmzr2gwr70ez72dorx82p
# 6802   4.355761  1.420843     L  bx0cdmzr2gwr70ez72dorx82p
# 6803   2.645890  1.084437     L  bx0cdmzr2gwr70ez72dorx82p
# 6804   4.645190 -2.394862     L  bx0cdmzr2gwr70ez72dorx82p
# 6805   3.206519  0.589411     L  bx0cdmzr2gwr70ez72dorx82p
# 6806   1.498425  0.630386     L  bx0cdmzr2gwr70ez72dorx82p
# 6807   1.327969  0.869005     R  bx0cdmzr2gwr70ez72dorx82p

# %%
df_events[df_events['event_description']=='Ball touch']
# Out:
#               id  eventId  event_type_id  current_phase  period_minute  \
# 38    2423549973       22             61              1              1
# 126   2423554205       58             61              1              5
# 150   2423555597       76             61              1              6
# 161   2423556435       77             61              1              7
# 163   2423556479       79             61              1              7
# ...          ...      ...            ...            ...            ...
# 1721  2423662741      877             61              2             90
# 1734  2423663399      884             61              2             90
# 1750  2423663971      891             61              2             91
# 1770  2423705563      819             61              2             92
# 1778  2423665319      901             61              2             92
#
#       period_second               contestantId  outcome     x     y  \
# 38               12  bx0cdmzr2gwr70ez72dorx82p        0  63.1  23.4
# 126              25  bx0cdmzr2gwr70ez72dorx82p        0  47.1  13.7
# 150              30  3c3jcs7vc1t6vz5lev162jyv7        0  55.8   4.7
# 161               7  bx0cdmzr2gwr70ez72dorx82p        0  73.4  54.8
# 163               8  3c3jcs7vc1t6vz5lev162jyv7        1  26.2  48.5
# ...             ...                        ...      ...   ...   ...
# 1721             12  bx0cdmzr2gwr70ez72dorx82p        0  60.4  94.5
# 1734             48  bx0cdmzr2gwr70ez72dorx82p        1  61.8  83.5
# 1750             26  bx0cdmzr2gwr70ez72dorx82p        0  67.1  97.9
# 1770             29  3c3jcs7vc1t6vz5lev162jyv7        1  66.6   6.5
# 1778             45  bx0cdmzr2gwr70ez72dorx82p        1  37.4  72.5
#
#               lastModified                                          qualifier  \
# 38    2022-05-22T06:36:45Z  [{'id': 3587586589, 'qualifierId': 21}, {'id':...
# 126   2022-05-22T06:35:53Z  [{'id': 3587595693, 'qualifierId': 15}, {'id':...
# 150   2022-05-22T06:35:42Z  [{'id': 3586120557, 'qualifierId': 56, 'value'...
# 161   2022-05-22T06:35:36Z  [{'id': 3587600013, 'qualifierId': 388}, {'id'...
# 163   2022-05-22T06:35:36Z  [{'id': 3586125289, 'qualifierId': 56, 'value'...
# ...                    ...                                                ...
# 1721  2022-05-22T06:19:12Z  [{'id': 3586711543, 'qualifierId': 56, 'value'...
# 1734  2022-05-22T06:19:08Z  [{'id': 3587613625, 'qualifierId': 178}, {'id'...
# 1750  2022-05-22T06:19:00Z  [{'id': 3587615021, 'qualifierId': 15}, {'id':...
# 1770  2022-05-22T06:18:53Z  [{'id': 3587616867, 'qualifierId': 178}, {'id'...
# 1778  2022-05-22T06:18:48Z  [{'id': 3587617707, 'qualifierId': 15}, {'id':...
#
#                        playerId lineBreakingPass.linesBroken.value  \
# 38    e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
# 126   e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
# 150    fvd7y3f6948713acbas7w3u2                                NaN
# 161   5qgc6zjc38a5xjl35gs7h3vu1                                NaN
# 163   96wcx761pzv5ub4sfwsynp51x                                NaN
# ...                         ...                                ...
# 1721  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 1734  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 1750  e3kdoxu1kwn2w3wwi1rqhvr9x                                NaN
# 1770  7ty1wdxxnusgkl34k5raipbl5                                NaN
# 1778  6j0ogojh2b7poyceg7i3k09yi                                NaN
#
#      passOption.player passTarget.player xThreat.applied  \
# 38                 NaN               NaN             NaN
# 126                NaN               NaN             NaN
# 150                NaN               NaN             NaN
# 161                NaN               NaN             NaN
# 163                NaN               NaN             NaN
# ...                ...               ...             ...
# 1721               NaN               NaN             NaN
# 1734               NaN               NaN             NaN
# 1750               NaN               NaN             NaN
# 1770               NaN               NaN             NaN
# 1778               NaN               NaN             NaN
#
#      lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 38                                     NaN                            high
# 126                                    NaN                            high
# 150                                    NaN                             low
# 161                                    NaN                            high
# 163                                    NaN                             NaN
# ...                                    ...                             ...
# 1721                                   NaN                          medium
# 1734                                   NaN                             NaN
# 1750                                   NaN                            high
# 1770                                   NaN                             NaN
# 1778                                   NaN                             NaN
#
#                                         pressure.player xThreat.removed  \
# 38    [{'playerId': '72d5uxwcmvhd6mzthxuvev1sl', 'sh...             NaN
# 126   [{'playerId': '976riwm0dz0e74d4l28y3ttcl', 'sh...             NaN
# 150   [{'playerId': '6j0ogojh2b7poyceg7i3k09yi', 'sh...             NaN
# 161   [{'playerId': '96wcx761pzv5ub4sfwsynp51x', 'sh...             NaN
# 163                                                 NaN             NaN
# ...                                                 ...             ...
# 1721  [{'playerId': 'fvd7y3f6948713acbas7w3u2', 'shi...             NaN
# 1734                                                NaN             NaN
# 1750  [{'playerId': '72d5uxwcmvhd6mzthxuvev1sl', 'sh...             NaN
# 1770                                                NaN             NaN
# 1778                                                NaN             NaN
#
#       keyPass  assist  timeelapsed event_description
# 38        NaN     NaN        72.52        Ball touch
# 126       NaN     NaN       325.20        Ball touch
# 150       NaN     NaN       390.20        Ball touch
# 161       NaN     NaN       427.32        Ball touch
# 163       NaN     NaN       428.08        Ball touch
# ...       ...     ...          ...               ...
# 1721      NaN     NaN      2712.80        Ball touch
# 1734      NaN     NaN      2748.92        Ball touch
# 1750      NaN     NaN      2786.60        Ball touch
# 1770      NaN     NaN      2849.36        Ball touch
# 1778      NaN     NaN      2865.88        Ball touch
#
# [67 rows x 25 columns]
