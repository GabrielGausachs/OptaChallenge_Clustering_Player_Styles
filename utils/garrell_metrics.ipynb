# %%
import pandas as pd
import json
import os
import numpy as np

pd.options.display.max_columns = 999

# %% [markdown]
# ### TRACKING DATA AND EVENTS

# %%
# load tracking data
current_directory = os.getcwd()
path_tracking = os.path.join(os.path.join(current_directory, 'data'), "tracking_set_0")
#print(path_tracking)
game_id = 1

df_tracking = pd.read_parquet(f'{path_tracking}/{game_id}_tracking.parquet')

# %%
# load events names
path_event_csv = os.path.join(current_directory,'data')
df_event_names = pd.read_csv(os.path.join(path_event_csv,'event_names.csv'))

dict_event_names = df_event_names.set_index('event_type_id').to_dict()['event_description']

# %%
# load event data
def load_event_data(file_name, base_path):
    # read in event file
    with open(f'{base_path}/{file_name}') as f:
        data=json.loads(f.read())

    f.close()
    
    # transform data into pandas dataframe
    df_events = pd.json_normalize(data['liveData']['event'])
    
    # preprocess event data and keep relevant information only

    # add timeelapsed to each event
    df_events['timestamp'] = pd.to_datetime(df_events.timeStamp).apply(lambda x: x.timestamp())

    df_events = df_events.query('periodId in [1,2]')

    def add_timeelapsed_to_events(df):
        start_time = df.query('typeId==32')['timestamp'].iloc[0]
        df['timestamp_new'] = np.int64((df['timestamp'] - start_time)*1000)

        df['timeelapsed'] = df['timestamp_new'].apply(lambda x: (40 * round(x/40))/1000)

        return df

    df_events = df_events.groupby('periodId').apply(add_timeelapsed_to_events)

    df_events = df_events.drop(columns=['timeStamp','timestamp','timestamp_new'])
    
    # rename some columns
    df_events = df_events.rename(columns=
        {
            'periodId':'current_phase',
            'typeId':'event_type_id',
            'timeMin':'period_minute',
            'timeSec':'period_second'
        }
    )
    
    return df_events

# %%
path_events = os.path.join(os.path.join(current_directory,'data'),"first_10_events")
#print(path_events)

event_file = f'{game_id}.json'

df_events = load_event_data(
    base_path=path_events,
    file_name=event_file
)

# add event descriptions
df_events['event_description'] = df_events['event_type_id'].map(dict_event_names)

# make a copy of it for later usage
events_all = df_events.copy()
# Out:
# C:\Users\alber\AppData\Local\Temp\ipykernel_23040\3763987763.py:27: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_events = df_events.groupby('periodId').apply(add_timeelapsed_to_events)

# %%
display(df_events.columns)
# Out:
# Index(['id', 'eventId', 'event_type_id', 'current_phase', 'period_minute',
#        'period_second', 'contestantId', 'outcome', 'x', 'y', 'lastModified',
#        'qualifier', 'playerId', 'lineBreakingPass.linesBroken.value',
#        'passOption.player', 'passTarget.player', 'xThreat.applied',
#        'lineBreakingPass.lastLineBroken.value',
#        'pressure.pressureReceived.value', 'pressure.player', 'xThreat.removed',
#        'keyPass', 'assist', 'timeelapsed', 'event_description'],
#       dtype='object')

# %% [markdown]
# ### QUALIFIERS

# %%
# Read in qualifier list
path_data = os.path.join(current_directory,'data')
qualifier_names = pd.read_csv(os.path.join(path_data,"qualifier_names.csv"))
#display(qualifier_names)

# Explode coverts each element in each list to a separate row
cols = ['id', 'qualifier']
qualifiers = events_all[cols].explode('qualifier')
#display(qualifiers.head())

qualifiers = qualifiers[qualifiers.qualifier.notna()].reset_index(drop=True)
#print(qualifiers.shape)
#display(qualifiers.head())

# save corresponding event ids for each qualifier
event_ids = qualifiers.id.tolist()

qualifiers = pd.json_normalize(qualifiers[qualifiers.qualifier.notna()]['qualifier'])
#print(qualifiers.shape)
#display(qualifiers.head())

qualifiers['event_id'] = event_ids
#display(qualifiers.head())

qualifiers = qualifiers.merge(qualifier_names, how='left', on='qualifierId')

# %%
display(qualifiers.head())
# Out:
#            id  qualifierId          value    event_id          qualifier
# 0  3586084711          127  Right to Left  2423549045  Direction of Play
# 1  3586084701          127  Left to Right  2423549041  Direction of Play
# 2  3586084825           56           Back  2423549063               Zone
# 3  3586084833          213            2.7  2423549063              Angle
# 4  3586084827          140           28.5  2423549063         Pass End X

# %% [markdown]
# ## MÈTRIQUES

# %%
display(df_events.head())
# Out:
#            id  eventId  event_type_id  current_phase  period_minute  \
# 2  2423549045        2             32              1              0
# 3  2423549041        2             32              1              0
# 4  2423549063        3              1              1              0
# 5  2423549097        4              1              1              0
# 6  2423549113        5              1              1              0
#
#    period_second               contestantId  outcome     x     y  \
# 2              0  3c3jcs7vc1t6vz5lev162jyv7        1   0.0   0.0
# 3              0  bx0cdmzr2gwr70ez72dorx82p        1   0.0   0.0
# 4              0  bx0cdmzr2gwr70ez72dorx82p        1  49.9  50.0
# 5              2  bx0cdmzr2gwr70ez72dorx82p        1  31.5  57.2
# 6              7  bx0cdmzr2gwr70ez72dorx82p        1  49.2  95.4
#
#            lastModified                                          qualifier  \
# 2  2022-05-22T03:17:52Z  [{'id': 3586084711, 'qualifierId': 127, 'value...
# 3  2022-05-21T18:59:34Z  [{'id': 3586084701, 'qualifierId': 127, 'value...
# 4  2022-05-22T03:34:41Z  [{'id': 3586084825, 'qualifierId': 56, 'value'...
# 5  2022-05-22T06:37:07Z  [{'id': 3586085043, 'qualifierId': 213, 'value...
# 6  2022-05-22T06:37:06Z  [{'id': 3586085129, 'qualifierId': 212, 'value...
#
#                     playerId lineBreakingPass.linesBroken.value  \
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 5  azuc3tma44xyrbgf5y279o1xx                                  0
# 6  7sep6mx2s67mh5fr3raxu7aei                                  1
#
#                                    passOption.player  \
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...
# 6  [{'playerId': '5qgc6zjc38a5xjl35gs7h3vu1', 'sh...
#
#                                    passTarget.player xThreat.applied  \
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 5  [{'playerId': '7sep6mx2s67mh5fr3raxu7aei', 'sh...    0.0029771626
# 6  [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...    0.0309752524
#
#   lineBreakingPass.lastLineBroken.value pressure.pressureReceived.value  \
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# 5                                   NaN                             NaN
# 6                          secondToLast                            high
#
#                                      pressure.player xThreat.removed  keyPass  \
# 2                                                NaN             NaN      NaN
# 3                                                NaN             NaN      NaN
# 4                                                NaN             NaN      NaN
# 5                                                NaN             NaN      NaN
# 6  [{'playerId': 'e6ok0deqkoe80184iu509gzu2', 'sh...             NaN      NaN
#
#    assist  timeelapsed event_description
# 2     NaN         0.00      Period start
# 3     NaN         0.00      Period start
# 4     NaN         0.04              Pass
# 5     NaN         2.84              Pass
# 6     NaN         7.88              Pass

# %%
def event_per_player(df, event, name, sort_by='playerId', ascending=True):
    df = df.dropna(subset=['playerId'])
    try:
        df = df[df['event_description'] == event]
        result_df = df.groupby('playerId').size().reset_index(name=name)
        result_df = result_df.sort_values(by=sort_by, ascending=ascending)
        result_df = result_df.reset_index(drop=True)
        return result_df
    except:
        print(f"Error: 'event_description' column not found in the DataFrame.")
        return False

# %% [markdown]
# ### Passes completats, intentats, totals, % success, keyPasses per jugador

# %%
df_passes = df_events[df_events['event_description']=='Pass']

# %%
passes_totals = event_per_player(df_passes,'Pass', 'Total_passes')

# %%
df_passes_completed = df_passes[df_passes['outcome']==1]
passes_completats = event_per_player(df_passes_completed,'Pass', 'Passes_completed')
#print(passes_completats)

# %%
df_passes_failed = df_passes[df_passes['outcome']==0]
passes_failed = event_per_player(df_passes_failed,'Pass', 'Passes_failed')
#print(passes_failed)

# %%
merged_df_passes = pd.merge(passes_totals, passes_completats, on='playerId', how='left')
merged_df_passes = pd.merge(merged_df_passes, passes_failed, on='playerId', how='left')
# Fill NaN values with 0 (for players who didn't have passes completed or failed)
merged_df_passes = merged_df_passes.fillna(0)
merged_df_passes[['Passes_completed', 'Passes_failed']] = merged_df_passes[['Passes_completed', 'Passes_failed']].astype(int)
merged_df_passes['%_pass_success'] = round((merged_df_passes['Passes_completed'] / merged_df_passes['Total_passes']) * 100,2)

# %%
display(merged_df_passes)
# Out:
#                      playerId  Total_passes  Passes_completed  Passes_failed  \
# 0   2lvit204llltk13iglsa2tjah             2                 1              1
# 1   3sc349yey596xp2j6xlyt0frp            54                44             10
# 2   3vx94h32ahujciraspdayj9t6            19                17              2
# 3   4u281v53ges3kimtgac0tidm2            52                42             10
# 4   5ak9fwtqlr2pll0nsv5br7p7u            20                12              8
# 5   5qgc6zjc38a5xjl35gs7h3vu1            36                26             10
# 6   6ekdnbnk56xlxforb5owt3dn9            47                39              8
# 7   6j0ogojh2b7poyceg7i3k09yi            64                58              6
# 8   6u2ob6fv950r1qve8uejkq2uh            59                50              9
# 9   72d5uxwcmvhd6mzthxuvev1sl            38                36              2
# 10  7cp51c8zn7y08iyk0hc9ix5nt            66                56             10
# 11  7k0r5crdh9blj3edt31zwy0dm             1                 0              1
# 12  7sep6mx2s67mh5fr3raxu7aei            42                33              9
# 13  8f3bhiy6r5eei1n25exhbwr8p            22                17              5
# 14  8gkexxgf3pypshhqwg6ibp7o4            35                32              3
# 15  8qmm84tue6kuz8e5nhhdhmz8p            41                32              9
# 16  96wcx761pzv5ub4sfwsynp51x            54                48              6
# 17  976riwm0dz0e74d4l28y3ttcl            55                45             10
# 18  a56woizbe4g6jpl3fg4tlgno5            24                20              4
# 19   afymbx9eo87zau8mo99pakbu            41                25             16
# 20  agwvouyocx93y39g7tmwaojx1             5                 5              0
# 21  azuc3tma44xyrbgf5y279o1xx            41                38              3
# 22  bvbebtykj45j3luvemk8yc4ph            41                34              7
# 23  ccu7hw3wrcspl1a18g2ldnsh5             6                 2              4
# 24  dxb1r4gqgxkngb0pzvfby9iol            13                11              2
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x            14                 7              7
# 26  e6ok0deqkoe80184iu509gzu2            29                22              7
# 27  e7e68wlpiqqohpg71oh4vrbl6            22                18              4
# 28   fvd7y3f6948713acbas7w3u2            37                31              6
# 29    vja0xo3xiuax8eh0b6q3y09            44                42              2
#
#     %_pass_success
# 0            50.00
# 1            81.48
# 2            89.47
# 3            80.77
# 4            60.00
# 5            72.22
# 6            82.98
# 7            90.62
# 8            84.75
# 9            94.74
# 10           84.85
# 11            0.00
# 12           78.57
# 13           77.27
# 14           91.43
# 15           78.05
# 16           88.89
# 17           81.82
# 18           83.33
# 19           60.98
# 20          100.00
# 21           92.68
# 22           82.93
# 23           33.33
# 24           84.62
# 25           50.00
# 26           75.86
# 27           81.82
# 28           83.78
# 29           95.45

# %%
df_keyPasses = df_passes[df_passes['keyPass']==True]

# %%
keyPasses = event_per_player(df_keyPasses, 'Pass', 'keyPasses')
display(keyPasses)
# Out:
#                     playerId  keyPasses
# 0  5ak9fwtqlr2pll0nsv5br7p7u          1
# 1  6j0ogojh2b7poyceg7i3k09yi          1
# 2  6u2ob6fv950r1qve8uejkq2uh          1
# 3  7sep6mx2s67mh5fr3raxu7aei          3
# 4  8gkexxgf3pypshhqwg6ibp7o4          1
# 5  96wcx761pzv5ub4sfwsynp51x          1
# 6  976riwm0dz0e74d4l28y3ttcl          1
# 7  bvbebtykj45j3luvemk8yc4ph          1
# 8    vja0xo3xiuax8eh0b6q3y09          1

# %%
# Merge key passes with the previously merged DataFrame
new_df_passes = pd.merge(merged_df_passes, keyPasses, on='playerId', how='left')
new_df_passes['keyPasses'] = new_df_passes['keyPasses'].fillna(0).astype(int)

# %%
# Display the resulting DataFrame
display(new_df_passes)
# Out:
#                      playerId  Total_passes  Passes_completed  Passes_failed  \
# 0   2lvit204llltk13iglsa2tjah             2                 1              1
# 1   3sc349yey596xp2j6xlyt0frp            54                44             10
# 2   3vx94h32ahujciraspdayj9t6            19                17              2
# 3   4u281v53ges3kimtgac0tidm2            52                42             10
# 4   5ak9fwtqlr2pll0nsv5br7p7u            20                12              8
# 5   5qgc6zjc38a5xjl35gs7h3vu1            36                26             10
# 6   6ekdnbnk56xlxforb5owt3dn9            47                39              8
# 7   6j0ogojh2b7poyceg7i3k09yi            64                58              6
# 8   6u2ob6fv950r1qve8uejkq2uh            59                50              9
# 9   72d5uxwcmvhd6mzthxuvev1sl            38                36              2
# 10  7cp51c8zn7y08iyk0hc9ix5nt            66                56             10
# 11  7k0r5crdh9blj3edt31zwy0dm             1                 0              1
# 12  7sep6mx2s67mh5fr3raxu7aei            42                33              9
# 13  8f3bhiy6r5eei1n25exhbwr8p            22                17              5
# 14  8gkexxgf3pypshhqwg6ibp7o4            35                32              3
# 15  8qmm84tue6kuz8e5nhhdhmz8p            41                32              9
# 16  96wcx761pzv5ub4sfwsynp51x            54                48              6
# 17  976riwm0dz0e74d4l28y3ttcl            55                45             10
# 18  a56woizbe4g6jpl3fg4tlgno5            24                20              4
# 19   afymbx9eo87zau8mo99pakbu            41                25             16
# 20  agwvouyocx93y39g7tmwaojx1             5                 5              0
# 21  azuc3tma44xyrbgf5y279o1xx            41                38              3
# 22  bvbebtykj45j3luvemk8yc4ph            41                34              7
# 23  ccu7hw3wrcspl1a18g2ldnsh5             6                 2              4
# 24  dxb1r4gqgxkngb0pzvfby9iol            13                11              2
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x            14                 7              7
# 26  e6ok0deqkoe80184iu509gzu2            29                22              7
# 27  e7e68wlpiqqohpg71oh4vrbl6            22                18              4
# 28   fvd7y3f6948713acbas7w3u2            37                31              6
# 29    vja0xo3xiuax8eh0b6q3y09            44                42              2
#
#     %_pass_success  keyPasses
# 0            50.00          0
# 1            81.48          0
# 2            89.47          0
# 3            80.77          0
# 4            60.00          1
# 5            72.22          0
# 6            82.98          0
# 7            90.62          1
# 8            84.75          1
# 9            94.74          0
# 10           84.85          0
# 11            0.00          0
# 12           78.57          3
# 13           77.27          0
# 14           91.43          1
# 15           78.05          0
# 16           88.89          1
# 17           81.82          1
# 18           83.33          0
# 19           60.98          0
# 20          100.00          0
# 21           92.68          0
# 22           82.93          1
# 23           33.33          0
# 24           84.62          0
# 25           50.00          0
# 26           75.86          0
# 27           81.82          0
# 28           83.78          0
# 29           95.45          1

# %%
new_df_passes.columns
# Out:
# Index(['playerId', 'Total_passes', 'Passes_completed', 'Passes_failed',
#        '%_pass_success', 'keyPasses'],
#       dtype='object')

# %% [markdown]
# ### Passes and Pressure Received

# %%
df_passes_pressure = df_passes.copy()
df_passes_pressure['pressure_received'] = df_passes_pressure['pressure.pressureReceived.value'].fillna('NaN')
df_passes_pressure = df_passes_pressure.drop('pressure.pressureReceived.value', axis=1)

# %%
display(df_passes_pressure.head(3))
# Out:
#            id  eventId  event_type_id  current_phase  period_minute  \
# 4  2423549063        3              1              1              0
# 5  2423549097        4              1              1              0
# 6  2423549113        5              1              1              0
#
#    period_second               contestantId  outcome     x     y  \
# 4              0  bx0cdmzr2gwr70ez72dorx82p        1  49.9  50.0
# 5              2  bx0cdmzr2gwr70ez72dorx82p        1  31.5  57.2
# 6              7  bx0cdmzr2gwr70ez72dorx82p        1  49.2  95.4
#
#            lastModified                                          qualifier  \
# 4  2022-05-22T03:34:41Z  [{'id': 3586084825, 'qualifierId': 56, 'value'...
# 5  2022-05-22T06:37:07Z  [{'id': 3586085043, 'qualifierId': 213, 'value...
# 6  2022-05-22T06:37:06Z  [{'id': 3586085129, 'qualifierId': 212, 'value...
#
#                     playerId lineBreakingPass.linesBroken.value  \
# 4  6u2ob6fv950r1qve8uejkq2uh                                NaN
# 5  azuc3tma44xyrbgf5y279o1xx                                  0
# 6  7sep6mx2s67mh5fr3raxu7aei                                  1
#
#                                    passOption.player  \
# 4                                                NaN
# 5  [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...
# 6  [{'playerId': '5qgc6zjc38a5xjl35gs7h3vu1', 'sh...
#
#                                    passTarget.player xThreat.applied  \
# 4                                                NaN             NaN
# 5  [{'playerId': '7sep6mx2s67mh5fr3raxu7aei', 'sh...    0.0029771626
# 6  [{'playerId': 'e3kdoxu1kwn2w3wwi1rqhvr9x', 'sh...    0.0309752524
#
#   lineBreakingPass.lastLineBroken.value  \
# 4                                   NaN
# 5                                   NaN
# 6                          secondToLast
#
#                                      pressure.player xThreat.removed  keyPass  \
# 4                                                NaN             NaN      NaN
# 5                                                NaN             NaN      NaN
# 6  [{'playerId': 'e6ok0deqkoe80184iu509gzu2', 'sh...             NaN      NaN
#
#    assist  timeelapsed event_description pressure_received
# 4     NaN         0.04              Pass               NaN
# 5     NaN         2.84              Pass               NaN
# 6     NaN         7.88              Pass              high

# %% [markdown]
# #### Passes Pressure NaN

# %%
df_pp_NaN = df_passes_pressure[df_passes_pressure['pressure_received']=='NaN']

# %%
passes_totals_NaN = event_per_player(df_pp_NaN,'Pass', 'Total_passes_NaN')

df_pp_NaN_completats = df_pp_NaN[df_pp_NaN['outcome']==1]
passes_completats_NaN = event_per_player(df_pp_NaN_completats,'Pass', 'Passes_completed_NaN')

df_pp_NaN_fallats = df_pp_NaN[df_pp_NaN['outcome']==0]
passes_fallats_NaN = event_per_player(df_pp_NaN_fallats,'Pass', 'Passes_fallats_NaN')

# %%
merged_df_passes_NaN = pd.merge(passes_totals_NaN, passes_completats_NaN, on='playerId', how='left')
merged_df_passes_NaN = pd.merge(merged_df_passes_NaN, passes_fallats_NaN, on='playerId', how='left')
# Fill NaN values with 0 (for players who didn't have passes completed or failed)
merged_df_passes_NaN = merged_df_passes_NaN.fillna(0)
merged_df_passes_NaN[['Passes_completed_NaN', 'Passes_fallats_NaN']] = merged_df_passes_NaN[['Passes_completed_NaN', 'Passes_fallats_NaN']].astype(int)
merged_df_passes_NaN['%_pass_success_NaN'] = round((merged_df_passes_NaN['Passes_completed_NaN'] / merged_df_passes_NaN['Total_passes_NaN']) * 100,2)

# %%
display(merged_df_passes_NaN)
# Out:
#                      playerId  Total_passes_NaN  Passes_completed_NaN  \
# 0   2lvit204llltk13iglsa2tjah                 1                     1
# 1   3sc349yey596xp2j6xlyt0frp                21                    17
# 2   3vx94h32ahujciraspdayj9t6                 4                     4
# 3   4u281v53ges3kimtgac0tidm2                20                    18
# 4   5ak9fwtqlr2pll0nsv5br7p7u                 5                     4
# 5   5qgc6zjc38a5xjl35gs7h3vu1                 7                     5
# 6   6ekdnbnk56xlxforb5owt3dn9                44                    37
# 7   6j0ogojh2b7poyceg7i3k09yi                15                    14
# 8   6u2ob6fv950r1qve8uejkq2uh                 7                     7
# 9   72d5uxwcmvhd6mzthxuvev1sl                23                    21
# 10  7cp51c8zn7y08iyk0hc9ix5nt                33                    31
# 11  7sep6mx2s67mh5fr3raxu7aei                12                    12
# 12  8f3bhiy6r5eei1n25exhbwr8p                 7                     7
# 13  8gkexxgf3pypshhqwg6ibp7o4                 9                     8
# 14  8qmm84tue6kuz8e5nhhdhmz8p                24                    22
# 15  96wcx761pzv5ub4sfwsynp51x                16                    15
# 16  976riwm0dz0e74d4l28y3ttcl                24                    20
# 17  a56woizbe4g6jpl3fg4tlgno5                23                    20
# 18   afymbx9eo87zau8mo99pakbu                19                    13
# 19  agwvouyocx93y39g7tmwaojx1                 4                     4
# 20  azuc3tma44xyrbgf5y279o1xx                36                    34
# 21  bvbebtykj45j3luvemk8yc4ph                12                    10
# 22  ccu7hw3wrcspl1a18g2ldnsh5                 4                     2
# 23  dxb1r4gqgxkngb0pzvfby9iol                 3                     3
# 24  e3kdoxu1kwn2w3wwi1rqhvr9x                 2                     2
# 25  e6ok0deqkoe80184iu509gzu2                 5                     4
# 26  e7e68wlpiqqohpg71oh4vrbl6                 1                     1
# 27   fvd7y3f6948713acbas7w3u2                 9                     7
# 28    vja0xo3xiuax8eh0b6q3y09                 9                     9
#
#     Passes_fallats_NaN  %_pass_success_NaN
# 0                    0              100.00
# 1                    4               80.95
# 2                    0              100.00
# 3                    2               90.00
# 4                    1               80.00
# 5                    2               71.43
# 6                    7               84.09
# 7                    1               93.33
# 8                    0              100.00
# 9                    2               91.30
# 10                   2               93.94
# 11                   0              100.00
# 12                   0              100.00
# 13                   1               88.89
# 14                   2               91.67
# 15                   1               93.75
# 16                   4               83.33
# 17                   3               86.96
# 18                   6               68.42
# 19                   0              100.00
# 20                   2               94.44
# 21                   2               83.33
# 22                   2               50.00
# 23                   0              100.00
# 24                   0              100.00
# 25                   1               80.00
# 26                   0              100.00
# 27                   2               77.78
# 28                   0              100.00

# %% [markdown]
# #### Passes Pressure Low

# %%
df_pp_Low = df_passes_pressure[df_passes_pressure['pressure_received']=='low']

# %%
passes_totals_Low = event_per_player(df_pp_Low,'Pass', 'Total_passes_Low')

df_pp_Low_completats = df_pp_Low[df_pp_Low['outcome']==1]
passes_completats_Low = event_per_player(df_pp_Low_completats,'Pass', 'Passes_completed_Low')

df_pp_Low_fallats = df_pp_Low[df_pp_Low['outcome']==0]
passes_fallats_Low = event_per_player(df_pp_Low_fallats,'Pass', 'Passes_fallats_Low')

# %%
merged_df_passes_Low = pd.merge(passes_totals_Low, passes_completats_Low, on='playerId', how='left')
merged_df_passes_Low = pd.merge(merged_df_passes_Low, passes_fallats_Low, on='playerId', how='left')
# Fill NaN values with 0 (for players who didn't have passes completed or failed)
merged_df_passes_Low = merged_df_passes_Low.fillna(0)
merged_df_passes_Low[['Passes_completed_Low', 'Passes_fallats_Low']] = merged_df_passes_Low[['Passes_completed_Low', 'Passes_fallats_Low']].astype(int)
merged_df_passes_Low['%_pass_success_Low'] = round((merged_df_passes_Low['Passes_completed_Low'] / merged_df_passes_Low['Total_passes_Low']) * 100,2)

# %%
display(merged_df_passes_Low)
# Out:
#                      playerId  Total_passes_Low  Passes_completed_Low  \
# 0   3vx94h32ahujciraspdayj9t6                 1                     1
# 1   4u281v53ges3kimtgac0tidm2                 4                     4
# 2   5ak9fwtqlr2pll0nsv5br7p7u                 2                     1
# 3   5qgc6zjc38a5xjl35gs7h3vu1                 3                     2
# 4   6j0ogojh2b7poyceg7i3k09yi                 8                     8
# 5   6u2ob6fv950r1qve8uejkq2uh                 9                     7
# 6   72d5uxwcmvhd6mzthxuvev1sl                 1                     1
# 7   7cp51c8zn7y08iyk0hc9ix5nt                10                    10
# 8   7sep6mx2s67mh5fr3raxu7aei                 6                     4
# 9   8f3bhiy6r5eei1n25exhbwr8p                 6                     3
# 10  8gkexxgf3pypshhqwg6ibp7o4                 2                     2
# 11  8qmm84tue6kuz8e5nhhdhmz8p                 1                     1
# 12  96wcx761pzv5ub4sfwsynp51x                 5                     5
# 13  976riwm0dz0e74d4l28y3ttcl                 2                     2
# 14  azuc3tma44xyrbgf5y279o1xx                 1                     1
# 15  bvbebtykj45j3luvemk8yc4ph                 1                     0
# 16  dxb1r4gqgxkngb0pzvfby9iol                 4                     4
# 17  e6ok0deqkoe80184iu509gzu2                 1                     1
# 18  e7e68wlpiqqohpg71oh4vrbl6                 4                     4
# 19   fvd7y3f6948713acbas7w3u2                 2                     2
# 20    vja0xo3xiuax8eh0b6q3y09                 4                     4
#
#     Passes_fallats_Low  %_pass_success_Low
# 0                    0              100.00
# 1                    0              100.00
# 2                    1               50.00
# 3                    1               66.67
# 4                    0              100.00
# 5                    2               77.78
# 6                    0              100.00
# 7                    0              100.00
# 8                    2               66.67
# 9                    3               50.00
# 10                   0              100.00
# 11                   0              100.00
# 12                   0              100.00
# 13                   0              100.00
# 14                   0              100.00
# 15                   1                0.00
# 16                   0              100.00
# 17                   0              100.00
# 18                   0              100.00
# 19                   0              100.00
# 20                   0              100.00

# %% [markdown]
# #### Passes Pressure Medium

# %%
df_pp_Medium = df_passes_pressure[df_passes_pressure['pressure_received']=='medium']

# %%
passes_totals_Medium = event_per_player(df_pp_Medium,'Pass', 'Total_passes_Medium')

df_pp_Medium_completats = df_pp_Medium[df_pp_Medium['outcome']==1]
passes_completats_Medium = event_per_player(df_pp_Medium_completats,'Pass', 'Passes_completed_Medium')

df_pp_Medium_fallats = df_pp_Medium[df_pp_Medium['outcome']==0]
passes_fallats_Medium = event_per_player(df_pp_Medium_fallats,'Pass', 'Passes_fallats_Medium')

# %%
merged_df_passes_Medium = pd.merge(passes_totals_Medium, passes_completats_Medium, on='playerId', how='left')
merged_df_passes_Medium = pd.merge(merged_df_passes_Medium, passes_fallats_Medium, on='playerId', how='left')
# Fill NaN values with 0 (for players who didn't have passes completed or failed)
merged_df_passes_Medium = merged_df_passes_Medium.fillna(0)
merged_df_passes_Medium[['Passes_completed_Medium', 'Passes_fallats_Medium']] = merged_df_passes_Medium[['Passes_completed_Medium', 'Passes_fallats_Medium']].astype(int)
merged_df_passes_Medium['%_pass_success_Medium'] = round((merged_df_passes_Medium['Passes_completed_Medium'] / merged_df_passes_Medium['Total_passes_Medium']) * 100,2)

# %%
display(merged_df_passes_Medium)
# Out:
#                      playerId  Total_passes_Medium  Passes_completed_Medium  \
# 0   3sc349yey596xp2j6xlyt0frp                   13                       11
# 1   3vx94h32ahujciraspdayj9t6                    3                        2
# 2   4u281v53ges3kimtgac0tidm2                   11                       10
# 3   5ak9fwtqlr2pll0nsv5br7p7u                    3                        2
# 4   5qgc6zjc38a5xjl35gs7h3vu1                    7                        6
# 5   6ekdnbnk56xlxforb5owt3dn9                    1                        1
# 6   6j0ogojh2b7poyceg7i3k09yi                   13                       12
# 7   6u2ob6fv950r1qve8uejkq2uh                   18                       16
# 8   72d5uxwcmvhd6mzthxuvev1sl                    4                        4
# 9   7cp51c8zn7y08iyk0hc9ix5nt                   12                       10
# 10  7sep6mx2s67mh5fr3raxu7aei                    7                        5
# 11  8f3bhiy6r5eei1n25exhbwr8p                    6                        6
# 12  8gkexxgf3pypshhqwg6ibp7o4                    8                        8
# 13  8qmm84tue6kuz8e5nhhdhmz8p                    7                        4
# 14  96wcx761pzv5ub4sfwsynp51x                   11                        9
# 15  976riwm0dz0e74d4l28y3ttcl                   16                       13
# 16   afymbx9eo87zau8mo99pakbu                   13                       10
# 17  azuc3tma44xyrbgf5y279o1xx                    1                        1
# 18  bvbebtykj45j3luvemk8yc4ph                   13                       12
# 19  dxb1r4gqgxkngb0pzvfby9iol                    4                        3
# 20  e3kdoxu1kwn2w3wwi1rqhvr9x                    3                        0
# 21  e6ok0deqkoe80184iu509gzu2                    4                        4
# 22  e7e68wlpiqqohpg71oh4vrbl6                    5                        5
# 23   fvd7y3f6948713acbas7w3u2                   12                       11
# 24    vja0xo3xiuax8eh0b6q3y09                   11                       10
#
#     Passes_fallats_Medium  %_pass_success_Medium
# 0                       2                  84.62
# 1                       1                  66.67
# 2                       1                  90.91
# 3                       1                  66.67
# 4                       1                  85.71
# 5                       0                 100.00
# 6                       1                  92.31
# 7                       2                  88.89
# 8                       0                 100.00
# 9                       2                  83.33
# 10                      2                  71.43
# 11                      0                 100.00
# 12                      0                 100.00
# 13                      3                  57.14
# 14                      2                  81.82
# 15                      3                  81.25
# 16                      3                  76.92
# 17                      0                 100.00
# 18                      1                  92.31
# 19                      1                  75.00
# 20                      3                   0.00
# 21                      0                 100.00
# 22                      0                 100.00
# 23                      1                  91.67
# 24                      1                  90.91

# %% [markdown]
# #### Passes Pressure High

# %%
df_pp_High = df_passes_pressure[df_passes_pressure['pressure_received']=='high']

# %%
passes_totals_High = event_per_player(df_pp_High,'Pass', 'Total_passes_High')

df_pp_High_completats = df_pp_High[df_pp_High['outcome']==1]
passes_completats_High = event_per_player(df_pp_High_completats,'Pass', 'Passes_completed_High')

df_pp_High_fallats = df_pp_High[df_pp_High['outcome']==0]
passes_fallats_High = event_per_player(df_pp_High_fallats,'Pass', 'Passes_fallats_High')

# %%
merged_df_passes_High = pd.merge(passes_totals_High, passes_completats_High, on='playerId', how='left')
merged_df_passes_High = pd.merge(merged_df_passes_High, passes_fallats_High, on='playerId', how='left')
# Fill NaN values with 0 (for players who didn't have passes completed or failed)
merged_df_passes_High = merged_df_passes_High.fillna(0)
merged_df_passes_High[['Passes_completed_High', 'Passes_fallats_High']] = merged_df_passes_High[['Passes_completed_High', 'Passes_fallats_High']].astype(int)
merged_df_passes_High['%_pass_success_High'] = round((merged_df_passes_High['Passes_completed_High'] / merged_df_passes_High['Total_passes_High']) * 100,2)

# %%
display(merged_df_passes_High)
# Out:
#                      playerId  Total_passes_High  Passes_completed_High  \
# 0   2lvit204llltk13iglsa2tjah                  1                      0
# 1   3sc349yey596xp2j6xlyt0frp                 20                     16
# 2   3vx94h32ahujciraspdayj9t6                 11                     10
# 3   4u281v53ges3kimtgac0tidm2                 17                     10
# 4   5ak9fwtqlr2pll0nsv5br7p7u                 10                      5
# 5   5qgc6zjc38a5xjl35gs7h3vu1                 19                     13
# 6   6ekdnbnk56xlxforb5owt3dn9                  2                      1
# 7   6j0ogojh2b7poyceg7i3k09yi                 28                     24
# 8   6u2ob6fv950r1qve8uejkq2uh                 25                     20
# 9   72d5uxwcmvhd6mzthxuvev1sl                 10                     10
# 10  7cp51c8zn7y08iyk0hc9ix5nt                 11                      5
# 11  7k0r5crdh9blj3edt31zwy0dm                  1                      0
# 12  7sep6mx2s67mh5fr3raxu7aei                 17                     12
# 13  8f3bhiy6r5eei1n25exhbwr8p                  3                      1
# 14  8gkexxgf3pypshhqwg6ibp7o4                 16                     14
# 15  8qmm84tue6kuz8e5nhhdhmz8p                  9                      5
# 16  96wcx761pzv5ub4sfwsynp51x                 22                     19
# 17  976riwm0dz0e74d4l28y3ttcl                 13                     10
# 18  a56woizbe4g6jpl3fg4tlgno5                  1                      0
# 19   afymbx9eo87zau8mo99pakbu                  9                      2
# 20  agwvouyocx93y39g7tmwaojx1                  1                      1
# 21  azuc3tma44xyrbgf5y279o1xx                  3                      2
# 22  bvbebtykj45j3luvemk8yc4ph                 15                     12
# 23  ccu7hw3wrcspl1a18g2ldnsh5                  2                      0
# 24  dxb1r4gqgxkngb0pzvfby9iol                  2                      1
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x                  9                      5
# 26  e6ok0deqkoe80184iu509gzu2                 19                     13
# 27  e7e68wlpiqqohpg71oh4vrbl6                 12                      8
# 28   fvd7y3f6948713acbas7w3u2                 14                     11
# 29    vja0xo3xiuax8eh0b6q3y09                 20                     19
#
#     Passes_fallats_High  %_pass_success_High
# 0                     1                 0.00
# 1                     4                80.00
# 2                     1                90.91
# 3                     7                58.82
# 4                     5                50.00
# 5                     6                68.42
# 6                     1                50.00
# 7                     4                85.71
# 8                     5                80.00
# 9                     0               100.00
# 10                    6                45.45
# 11                    1                 0.00
# 12                    5                70.59
# 13                    2                33.33
# 14                    2                87.50
# 15                    4                55.56
# 16                    3                86.36
# 17                    3                76.92
# 18                    1                 0.00
# 19                    7                22.22
# 20                    0               100.00
# 21                    1                66.67
# 22                    3                80.00
# 23                    2                 0.00
# 24                    1                50.00
# 25                    4                55.56
# 26                    6                68.42
# 27                    4                66.67
# 28                    3                78.57
# 29                    1                95.00

# %% [markdown]
# #### Taules amb totals/attempted/failed i % conversion rate per cada pressure i en total, i totals amb % unicament

# %%
# Merge the DataFrames
#merged_df_passes_TP -> TP = Total and Pressure
merged_df_passes_TP = pd.merge(merged_df_passes, merged_df_passes_NaN, on='playerId', how='left')
merged_df_passes_TP = pd.merge(merged_df_passes_TP, merged_df_passes_Low, on='playerId', how='left')
merged_df_passes_TP = pd.merge(merged_df_passes_TP, merged_df_passes_Medium, on='playerId', how='left')
merged_df_passes_TP = pd.merge(merged_df_passes_TP, merged_df_passes_High, on='playerId', how='left')

# %%
display(merged_df_passes_TP)
# Out:
#                      playerId  Total_passes  Passes_completed  Passes_failed  \
# 0   2lvit204llltk13iglsa2tjah             2                 1              1
# 1   3sc349yey596xp2j6xlyt0frp            54                44             10
# 2   3vx94h32ahujciraspdayj9t6            19                17              2
# 3   4u281v53ges3kimtgac0tidm2            52                42             10
# 4   5ak9fwtqlr2pll0nsv5br7p7u            20                12              8
# 5   5qgc6zjc38a5xjl35gs7h3vu1            36                26             10
# 6   6ekdnbnk56xlxforb5owt3dn9            47                39              8
# 7   6j0ogojh2b7poyceg7i3k09yi            64                58              6
# 8   6u2ob6fv950r1qve8uejkq2uh            59                50              9
# 9   72d5uxwcmvhd6mzthxuvev1sl            38                36              2
# 10  7cp51c8zn7y08iyk0hc9ix5nt            66                56             10
# 11  7k0r5crdh9blj3edt31zwy0dm             1                 0              1
# 12  7sep6mx2s67mh5fr3raxu7aei            42                33              9
# 13  8f3bhiy6r5eei1n25exhbwr8p            22                17              5
# 14  8gkexxgf3pypshhqwg6ibp7o4            35                32              3
# 15  8qmm84tue6kuz8e5nhhdhmz8p            41                32              9
# 16  96wcx761pzv5ub4sfwsynp51x            54                48              6
# 17  976riwm0dz0e74d4l28y3ttcl            55                45             10
# 18  a56woizbe4g6jpl3fg4tlgno5            24                20              4
# 19   afymbx9eo87zau8mo99pakbu            41                25             16
# 20  agwvouyocx93y39g7tmwaojx1             5                 5              0
# 21  azuc3tma44xyrbgf5y279o1xx            41                38              3
# 22  bvbebtykj45j3luvemk8yc4ph            41                34              7
# 23  ccu7hw3wrcspl1a18g2ldnsh5             6                 2              4
# 24  dxb1r4gqgxkngb0pzvfby9iol            13                11              2
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x            14                 7              7
# 26  e6ok0deqkoe80184iu509gzu2            29                22              7
# 27  e7e68wlpiqqohpg71oh4vrbl6            22                18              4
# 28   fvd7y3f6948713acbas7w3u2            37                31              6
# 29    vja0xo3xiuax8eh0b6q3y09            44                42              2
#
#     %_pass_success  Total_passes_NaN  Passes_completed_NaN  \
# 0            50.00               1.0                   1.0
# 1            81.48              21.0                  17.0
# 2            89.47               4.0                   4.0
# 3            80.77              20.0                  18.0
# 4            60.00               5.0                   4.0
# 5            72.22               7.0                   5.0
# 6            82.98              44.0                  37.0
# 7            90.62              15.0                  14.0
# 8            84.75               7.0                   7.0
# 9            94.74              23.0                  21.0
# 10           84.85              33.0                  31.0
# 11            0.00               NaN                   NaN
# 12           78.57              12.0                  12.0
# 13           77.27               7.0                   7.0
# 14           91.43               9.0                   8.0
# 15           78.05              24.0                  22.0
# 16           88.89              16.0                  15.0
# 17           81.82              24.0                  20.0
# 18           83.33              23.0                  20.0
# 19           60.98              19.0                  13.0
# 20          100.00               4.0                   4.0
# 21           92.68              36.0                  34.0
# 22           82.93              12.0                  10.0
# 23           33.33               4.0                   2.0
# 24           84.62               3.0                   3.0
# 25           50.00               2.0                   2.0
# 26           75.86               5.0                   4.0
# 27           81.82               1.0                   1.0
# 28           83.78               9.0                   7.0
# 29           95.45               9.0                   9.0
#
#     Passes_fallats_NaN  %_pass_success_NaN  Total_passes_Low  \
# 0                  0.0              100.00               NaN
# 1                  4.0               80.95               NaN
# 2                  0.0              100.00               1.0
# 3                  2.0               90.00               4.0
# 4                  1.0               80.00               2.0
# 5                  2.0               71.43               3.0
# 6                  7.0               84.09               NaN
# 7                  1.0               93.33               8.0
# 8                  0.0              100.00               9.0
# 9                  2.0               91.30               1.0
# 10                 2.0               93.94              10.0
# 11                 NaN                 NaN               NaN
# 12                 0.0              100.00               6.0
# 13                 0.0              100.00               6.0
# 14                 1.0               88.89               2.0
# 15                 2.0               91.67               1.0
# 16                 1.0               93.75               5.0
# 17                 4.0               83.33               2.0
# 18                 3.0               86.96               NaN
# 19                 6.0               68.42               NaN
# 20                 0.0              100.00               NaN
# 21                 2.0               94.44               1.0
# 22                 2.0               83.33               1.0
# 23                 2.0               50.00               NaN
# 24                 0.0              100.00               4.0
# 25                 0.0              100.00               NaN
# 26                 1.0               80.00               1.0
# 27                 0.0              100.00               4.0
# 28                 2.0               77.78               2.0
# 29                 0.0              100.00               4.0
#
#     Passes_completed_Low  Passes_fallats_Low  %_pass_success_Low  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    1.0                 0.0              100.00
# 3                    4.0                 0.0              100.00
# 4                    1.0                 1.0               50.00
# 5                    2.0                 1.0               66.67
# 6                    NaN                 NaN                 NaN
# 7                    8.0                 0.0              100.00
# 8                    7.0                 2.0               77.78
# 9                    1.0                 0.0              100.00
# 10                  10.0                 0.0              100.00
# 11                   NaN                 NaN                 NaN
# 12                   4.0                 2.0               66.67
# 13                   3.0                 3.0               50.00
# 14                   2.0                 0.0              100.00
# 15                   1.0                 0.0              100.00
# 16                   5.0                 0.0              100.00
# 17                   2.0                 0.0              100.00
# 18                   NaN                 NaN                 NaN
# 19                   NaN                 NaN                 NaN
# 20                   NaN                 NaN                 NaN
# 21                   1.0                 0.0              100.00
# 22                   0.0                 1.0                0.00
# 23                   NaN                 NaN                 NaN
# 24                   4.0                 0.0              100.00
# 25                   NaN                 NaN                 NaN
# 26                   1.0                 0.0              100.00
# 27                   4.0                 0.0              100.00
# 28                   2.0                 0.0              100.00
# 29                   4.0                 0.0              100.00
#
#     Total_passes_Medium  Passes_completed_Medium  Passes_fallats_Medium  \
# 0                   NaN                      NaN                    NaN
# 1                  13.0                     11.0                    2.0
# 2                   3.0                      2.0                    1.0
# 3                  11.0                     10.0                    1.0
# 4                   3.0                      2.0                    1.0
# 5                   7.0                      6.0                    1.0
# 6                   1.0                      1.0                    0.0
# 7                  13.0                     12.0                    1.0
# 8                  18.0                     16.0                    2.0
# 9                   4.0                      4.0                    0.0
# 10                 12.0                     10.0                    2.0
# 11                  NaN                      NaN                    NaN
# 12                  7.0                      5.0                    2.0
# 13                  6.0                      6.0                    0.0
# 14                  8.0                      8.0                    0.0
# 15                  7.0                      4.0                    3.0
# 16                 11.0                      9.0                    2.0
# 17                 16.0                     13.0                    3.0
# 18                  NaN                      NaN                    NaN
# 19                 13.0                     10.0                    3.0
# 20                  NaN                      NaN                    NaN
# 21                  1.0                      1.0                    0.0
# 22                 13.0                     12.0                    1.0
# 23                  NaN                      NaN                    NaN
# 24                  4.0                      3.0                    1.0
# 25                  3.0                      0.0                    3.0
# 26                  4.0                      4.0                    0.0
# 27                  5.0                      5.0                    0.0
# 28                 12.0                     11.0                    1.0
# 29                 11.0                     10.0                    1.0
#
#     %_pass_success_Medium  Total_passes_High  Passes_completed_High  \
# 0                     NaN                  1                      0
# 1                   84.62                 20                     16
# 2                   66.67                 11                     10
# 3                   90.91                 17                     10
# 4                   66.67                 10                      5
# 5                   85.71                 19                     13
# 6                  100.00                  2                      1
# 7                   92.31                 28                     24
# 8                   88.89                 25                     20
# 9                  100.00                 10                     10
# 10                  83.33                 11                      5
# 11                    NaN                  1                      0
# 12                  71.43                 17                     12
# 13                 100.00                  3                      1
# 14                 100.00                 16                     14
# 15                  57.14                  9                      5
# 16                  81.82                 22                     19
# 17                  81.25                 13                     10
# 18                    NaN                  1                      0
# 19                  76.92                  9                      2
# 20                    NaN                  1                      1
# 21                 100.00                  3                      2
# 22                  92.31                 15                     12
# 23                    NaN                  2                      0
# 24                  75.00                  2                      1
# 25                   0.00                  9                      5
# 26                 100.00                 19                     13
# 27                 100.00                 12                      8
# 28                  91.67                 14                     11
# 29                  90.91                 20                     19
#
#     Passes_fallats_High  %_pass_success_High
# 0                     1                 0.00
# 1                     4                80.00
# 2                     1                90.91
# 3                     7                58.82
# 4                     5                50.00
# 5                     6                68.42
# 6                     1                50.00
# 7                     4                85.71
# 8                     5                80.00
# 9                     0               100.00
# 10                    6                45.45
# 11                    1                 0.00
# 12                    5                70.59
# 13                    2                33.33
# 14                    2                87.50
# 15                    4                55.56
# 16                    3                86.36
# 17                    3                76.92
# 18                    1                 0.00
# 19                    7                22.22
# 20                    0               100.00
# 21                    1                66.67
# 22                    3                80.00
# 23                    2                 0.00
# 24                    1                50.00
# 25                    4                55.56
# 26                    6                68.42
# 27                    4                66.67
# 28                    3                78.57
# 29                    1                95.00

# %%
selected_columns = ['playerId',
                    'Total_passes', '%_pass_success',
                    'Total_passes_NaN', '%_pass_success_NaN',
                    'Total_passes_Low', '%_pass_success_Low',
                    'Total_passes_Medium', '%_pass_success_Medium',
                    'Total_passes_High', '%_pass_success_High']

merged_df_passes_pressure_overall = merged_df_passes_TP[selected_columns].copy()

# %%
display(merged_df_passes_pressure_overall)
# Out:
#                      playerId  Total_passes  %_pass_success  Total_passes_NaN  \
# 0   2lvit204llltk13iglsa2tjah             2           50.00               1.0
# 1   3sc349yey596xp2j6xlyt0frp            54           81.48              21.0
# 2   3vx94h32ahujciraspdayj9t6            19           89.47               4.0
# 3   4u281v53ges3kimtgac0tidm2            52           80.77              20.0
# 4   5ak9fwtqlr2pll0nsv5br7p7u            20           60.00               5.0
# 5   5qgc6zjc38a5xjl35gs7h3vu1            36           72.22               7.0
# 6   6ekdnbnk56xlxforb5owt3dn9            47           82.98              44.0
# 7   6j0ogojh2b7poyceg7i3k09yi            64           90.62              15.0
# 8   6u2ob6fv950r1qve8uejkq2uh            59           84.75               7.0
# 9   72d5uxwcmvhd6mzthxuvev1sl            38           94.74              23.0
# 10  7cp51c8zn7y08iyk0hc9ix5nt            66           84.85              33.0
# 11  7k0r5crdh9blj3edt31zwy0dm             1            0.00               NaN
# 12  7sep6mx2s67mh5fr3raxu7aei            42           78.57              12.0
# 13  8f3bhiy6r5eei1n25exhbwr8p            22           77.27               7.0
# 14  8gkexxgf3pypshhqwg6ibp7o4            35           91.43               9.0
# 15  8qmm84tue6kuz8e5nhhdhmz8p            41           78.05              24.0
# 16  96wcx761pzv5ub4sfwsynp51x            54           88.89              16.0
# 17  976riwm0dz0e74d4l28y3ttcl            55           81.82              24.0
# 18  a56woizbe4g6jpl3fg4tlgno5            24           83.33              23.0
# 19   afymbx9eo87zau8mo99pakbu            41           60.98              19.0
# 20  agwvouyocx93y39g7tmwaojx1             5          100.00               4.0
# 21  azuc3tma44xyrbgf5y279o1xx            41           92.68              36.0
# 22  bvbebtykj45j3luvemk8yc4ph            41           82.93              12.0
# 23  ccu7hw3wrcspl1a18g2ldnsh5             6           33.33               4.0
# 24  dxb1r4gqgxkngb0pzvfby9iol            13           84.62               3.0
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x            14           50.00               2.0
# 26  e6ok0deqkoe80184iu509gzu2            29           75.86               5.0
# 27  e7e68wlpiqqohpg71oh4vrbl6            22           81.82               1.0
# 28   fvd7y3f6948713acbas7w3u2            37           83.78               9.0
# 29    vja0xo3xiuax8eh0b6q3y09            44           95.45               9.0
#
#     %_pass_success_NaN  Total_passes_Low  %_pass_success_Low  \
# 0               100.00               NaN                 NaN
# 1                80.95               NaN                 NaN
# 2               100.00               1.0              100.00
# 3                90.00               4.0              100.00
# 4                80.00               2.0               50.00
# 5                71.43               3.0               66.67
# 6                84.09               NaN                 NaN
# 7                93.33               8.0              100.00
# 8               100.00               9.0               77.78
# 9                91.30               1.0              100.00
# 10               93.94              10.0              100.00
# 11                 NaN               NaN                 NaN
# 12              100.00               6.0               66.67
# 13              100.00               6.0               50.00
# 14               88.89               2.0              100.00
# 15               91.67               1.0              100.00
# 16               93.75               5.0              100.00
# 17               83.33               2.0              100.00
# 18               86.96               NaN                 NaN
# 19               68.42               NaN                 NaN
# 20              100.00               NaN                 NaN
# 21               94.44               1.0              100.00
# 22               83.33               1.0                0.00
# 23               50.00               NaN                 NaN
# 24              100.00               4.0              100.00
# 25              100.00               NaN                 NaN
# 26               80.00               1.0              100.00
# 27              100.00               4.0              100.00
# 28               77.78               2.0              100.00
# 29              100.00               4.0              100.00
#
#     Total_passes_Medium  %_pass_success_Medium  Total_passes_High  \
# 0                   NaN                    NaN                  1
# 1                  13.0                  84.62                 20
# 2                   3.0                  66.67                 11
# 3                  11.0                  90.91                 17
# 4                   3.0                  66.67                 10
# 5                   7.0                  85.71                 19
# 6                   1.0                 100.00                  2
# 7                  13.0                  92.31                 28
# 8                  18.0                  88.89                 25
# 9                   4.0                 100.00                 10
# 10                 12.0                  83.33                 11
# 11                  NaN                    NaN                  1
# 12                  7.0                  71.43                 17
# 13                  6.0                 100.00                  3
# 14                  8.0                 100.00                 16
# 15                  7.0                  57.14                  9
# 16                 11.0                  81.82                 22
# 17                 16.0                  81.25                 13
# 18                  NaN                    NaN                  1
# 19                 13.0                  76.92                  9
# 20                  NaN                    NaN                  1
# 21                  1.0                 100.00                  3
# 22                 13.0                  92.31                 15
# 23                  NaN                    NaN                  2
# 24                  4.0                  75.00                  2
# 25                  3.0                   0.00                  9
# 26                  4.0                 100.00                 19
# 27                  5.0                 100.00                 12
# 28                 12.0                  91.67                 14
# 29                 11.0                  90.91                 20
#
#     %_pass_success_High
# 0                  0.00
# 1                 80.00
# 2                 90.91
# 3                 58.82
# 4                 50.00
# 5                 68.42
# 6                 50.00
# 7                 85.71
# 8                 80.00
# 9                100.00
# 10                45.45
# 11                 0.00
# 12                70.59
# 13                33.33
# 14                87.50
# 15                55.56
# 16                86.36
# 17                76.92
# 18                 0.00
# 19                22.22
# 20               100.00
# 21                66.67
# 22                80.00
# 23                 0.00
# 24                50.00
# 25                55.56
# 26                68.42
# 27                66.67
# 28                78.57
# 29                95.00

# %% [markdown]
# #### Taula amb Passes totals intentats per Pressure

# %%
# Pivot the DataFrame
passes_count_pivot = df_passes_pressure.pivot_table(
    index='playerId',
    columns='pressure_received',
    values='eventId',
    aggfunc='count',
    fill_value=0
)

# Flatten the columns
passes_count_pivot.columns = passes_count_pivot.columns.map('_'.join)

# Reset the index
passes_count_pivot.reset_index(inplace=True)

passes_count_pivot.columns = ['playerId', 'pressure_NaN', 'pressure_High', 'pressure_Low', 'pressure_Medium']
passes_count_pivot.columns.name = None
passes_count_pivot = passes_count_pivot[['playerId', 'pressure_NaN', 'pressure_Low', 'pressure_Medium', 'pressure_High']]

# %%
display(passes_count_pivot)
# Out:
#                      playerId  pressure_NaN  pressure_Low  pressure_Medium  \
# 0   2lvit204llltk13iglsa2tjah             1             0                0
# 1   3sc349yey596xp2j6xlyt0frp            21             0               13
# 2   3vx94h32ahujciraspdayj9t6             4             1                3
# 3   4u281v53ges3kimtgac0tidm2            20             4               11
# 4   5ak9fwtqlr2pll0nsv5br7p7u             5             2                3
# 5   5qgc6zjc38a5xjl35gs7h3vu1             7             3                7
# 6   6ekdnbnk56xlxforb5owt3dn9            44             0                1
# 7   6j0ogojh2b7poyceg7i3k09yi            15             8               13
# 8   6u2ob6fv950r1qve8uejkq2uh             7             9               18
# 9   72d5uxwcmvhd6mzthxuvev1sl            23             1                4
# 10  7cp51c8zn7y08iyk0hc9ix5nt            33            10               12
# 11  7k0r5crdh9blj3edt31zwy0dm             0             0                0
# 12  7sep6mx2s67mh5fr3raxu7aei            12             6                7
# 13  8f3bhiy6r5eei1n25exhbwr8p             7             6                6
# 14  8gkexxgf3pypshhqwg6ibp7o4             9             2                8
# 15  8qmm84tue6kuz8e5nhhdhmz8p            24             1                7
# 16  96wcx761pzv5ub4sfwsynp51x            16             5               11
# 17  976riwm0dz0e74d4l28y3ttcl            24             2               16
# 18  a56woizbe4g6jpl3fg4tlgno5            23             0                0
# 19   afymbx9eo87zau8mo99pakbu            19             0               13
# 20  agwvouyocx93y39g7tmwaojx1             4             0                0
# 21  azuc3tma44xyrbgf5y279o1xx            36             1                1
# 22  bvbebtykj45j3luvemk8yc4ph            12             1               13
# 23  ccu7hw3wrcspl1a18g2ldnsh5             4             0                0
# 24  dxb1r4gqgxkngb0pzvfby9iol             3             4                4
# 25  e3kdoxu1kwn2w3wwi1rqhvr9x             2             0                3
# 26  e6ok0deqkoe80184iu509gzu2             5             1                4
# 27  e7e68wlpiqqohpg71oh4vrbl6             1             4                5
# 28   fvd7y3f6948713acbas7w3u2             9             2               12
# 29    vja0xo3xiuax8eh0b6q3y09             9             4               11
#
#     pressure_High
# 0               1
# 1              20
# 2              11
# 3              17
# 4              10
# 5              19
# 6               2
# 7              28
# 8              25
# 9              10
# 10             11
# 11              1
# 12             17
# 13              3
# 14             16
# 15              9
# 16             22
# 17             13
# 18              1
# 19              9
# 20              1
# 21              3
# 22             15
# 23              2
# 24              2
# 25              9
# 26             19
# 27             12
# 28             14
# 29             20
